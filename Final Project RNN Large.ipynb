# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./trainlyrics.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 106526624
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of rock lyrics.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        self.num_layers = 16
        
        self.rnn = nn.RNN(self.input_size, self.hidden_size, num_layers=self.num_layers, dropout=0.2)
        self.linear = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        output, hidden = self.rnn(input, hidden)
        output = self.linear(output)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(self.num_layers, self.hidden_size).to(device) #made into a 2d tensor. 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (rnn): RNN(100, 100, num_layers=16, dropout=0.2)
#   (linear): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
# NOTE: You may reduce the number of training iterations if the training takes long.
iters       = 40000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.001) #increased learning rate from 0.001 to 0.01
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/40000 loss:3.3095245361328125
# generated sequence: Wwlh i  oo hs laslsa iwr  ss
# a
# to{ voealoy uagl a)
# helshoasbv oiaynaBlsdBog  oyucat g,blhgoogingco ea
#
# iter:199/40000 loss:3.1596739292144775
# generated sequence: Wr hoatrte L   to
#  o  eg
# Tmcohi nasi irr o
# wdleth kng tl rhoa eBerwuokh nyltto"abtyo"o een efo lt u a
#
# iter:299/40000 loss:3.161419630050659
# generated sequence: Wyo,nmt'Syoianshrnrev o usn.t a , n avnno a ewldueo fw' htu,dnesnelmg r ah ohog'oiI
# hyb(tusggc e'sm p
#
# iter:399/40000 loss:3.1493477821350098
# generated sequence: Wtoebonmmticagtunf n n'Ihlalrnh hGy anedd nnhsndntprehlgIeloh mbBgik ,uwr dnlgutm,eLitneh a eem ahh o
#
# iter:499/40000 loss:3.1844394207000732
# generated sequence: Wlgtet ba
# wm  ss ,a  dl enhho  ia do
# a l mtd epnl
# tswgYo k lIomofio  teuep neu i"oro , Ieea hy ea
#
#
# iter:599/40000 loss:3.176910400390625
# generated sequence: WldIar o
# ynsto'h ryatd) hwIeanwy'tnaison, lerururl ouahc Nytywyi'ot  C'  yo o caew s   ealsdatitto'sp
#
# iter:699/40000 loss:3.2130019664764404
# generated sequence: Wtoaiudpetr greoa  opt elef kwna no   mna
# th IseuaeiA hs.o tfednh lhe"a'ne popehoef chnh mowrltrhnn l
#
# iter:799/40000 loss:3.193286418914795
# generated sequence: W l gi
#  nvwaahhaai,hsvgYregete yaah
# ntifl
# ltymde i'do t bet guy
# e  hn
# sbpInackhhs
# s  twdd ynBghssan
# s
#
# iter:899/40000 loss:3.2064473628997803
# generated sequence: W
# t evwYoci
#
# hiao'ah obeteo  ,T lhe oAaemyi
# so  n'oxte
# reoeoklefosnowknloko gidcn c n he
# k
# tirc ryooa
#
# iter:999/40000 loss:3.1613194942474365
# generated sequence: War g ont nu dynSld' n Heihee
# nnd fo oOaoRm  ro hi iitaam
# Sgmwfogec d,o
# olme
# TNTlsh   nh-. ftyreg etF
#
# iter:1099/40000 loss:3.1980621814727783
# generated sequence: Wdont(
# uaa urlan bo haegkonfhIeet h n  lf, iuIoe il fawty'gtbgdntttlnu wueamast'evi dgdn ds
# mukeywrn
#
# iter:1199/40000 loss:3.1601169109344482
# generated sequence: Wo dtopt snk cf l dn  niht aohe
# ntgc sAlir
# cdued watasioh
#  ofkmkmuahhef gi ou-matv ehdaIrui wafu dehl
#
# iter:1299/40000 loss:3.1669270992279053
# generated sequence: W,yse antn r etvlhotviloenht
#  fntaodm oemnw anhi
#  t eDo
# JBFReh e oieHaklltiiay uoeod aoh ' anor
# o  o
#
# iter:1399/40000 loss:3.1616485118865967
# generated sequence: W
# irtminny' s
#  oiy aywsmoi I hietsenrl htdof te enuoa' cl lhem nk d "n
# drgigfsdldnaeheAaonsin fJoeia
#
# iter:1499/40000 loss:3.172475576400757
# generated sequence: W
# ? s swwt baauBn'Nyaop rot eea oae m   o osmautstta o.uy'oear
# e wh lia Hrfs vTa taeee behe/o
# go s Ih
#
# iter:1599/40000 loss:3.169609308242798
# generated sequence: W sreietvo tels
# redosnteiIytwsm
#  adg
# rrui aotianvpnn' dg a em  s
# tenu  o
# " fsaao
# rmoadO to  e v Y oe
#
# iter:1699/40000 loss:3.178173065185547
# generated sequence: Wrnro
# t  nnhy hgnamolySn,iripwu unmn mheceyT'i tet cg S o
# eea
#
# iWnefoIn yc srsmoeetik
# d gy f
# imnhnieh
#
# iter:1799/40000 loss:3.170332193374634
# generated sequence: W nd  s t errap
#
#
# ifee' cuvtauwleennet oetn aiaod eehiyrd
# e owwhlhpr umelui bado
# awendm  ehatt,n og
#
# iter:1899/40000 loss:3.142991542816162
# generated sequence: Wfkk'etoiiie anohsdW g,oiao ore',
# gsemiar', yrae meaiapo
# la fl (m tmdyi ofeoo   lyuG r neh,as ,rvery
#
# iter:1999/40000 loss:3.2061760425567627
# generated sequence: Who awfOni ml  a ommte  l
# i'unhf ol tva-y uaSwl uymhut eehay" npo,d y taeni  T  n t hu al nosrste  my
#
# iter:2099/40000 loss:3.1713674068450928
# generated sequence: Wrr
# g   m  eegtascee i ooe ta toluodedd  Dw eodsrn
# ssuw o latoLaLueye e mue
# op
# reg
# s  l yyesousc td
#
# iter:2199/40000 loss:3.1725986003875732
# generated sequence: WorOtaoCr'o   soou  w tta  o e nmintnme  nsesmgav  l R'loeh  ehm ctchiITsn"Y epia B
# deo
# uIwfas obiown
#
# iter:2299/40000 loss:3.156447649002075
# generated sequence: WoLoyt yyalIveat AI uebeta s  bdni rhd
# ctuh' epj edybv ,A
#  usldo  aoye enyhywieo m"olnva
# y eleostw
#
# iter:2399/40000 loss:3.1705636978149414
# generated sequence: We  citntgn
# piuidak b'beubcy qhseteitt?'htn
#  leoi  awfifm eonllgseiho)eycon nSgoC wbBu )tf  e rumi t
#
# iter:2499/40000 loss:3.1676716804504395
# generated sequence: W rtn itnn teohomh  synloDoe
# sovmnodehsotuoCwlotl
# (er
# etnikos nh,
#   tt
# teeei  etWmf"5
# u
# sheo
# u'thcud
#
# iter:2599/40000 loss:3.1631665229797363
# generated sequence: W
#  ui sisy ayut  rvt ouT
# ?o sfaby orbe etl aW rhk th  ho mdurtadefee do damed oimGd io (getoreulitg
#
#
# iter:2699/40000 loss:3.216139554977417
# generated sequence: Wa ge/tie thd
# dnlheIed
# dsde.rfaerwbnwosoe crug e  td dmo  a dnslt  e drael lcamfkyCf
# uanon ior cmeod
#
# iter:2799/40000 loss:3.1648151874542236
# generated sequence: Wtslleet  gueosdrna t  wo binaa
# ene irr tB
# ulrd a
# s guMden int  iathn rkIttlatewsbae na
# T d' R woTio
#
# iter:2899/40000 loss:3.1394314765930176
# generated sequence: Wm
# day  ycTdkr si elS
# oe a
# ' u eaDsteadoet"etn,wylgeIetoenaoggluIVbpefbnws
# ae o Yao leti rBid se dk
#
# iter:2999/40000 loss:3.166402578353882
# generated sequence: W aoW
# m s e
# csatn'osthl  a(
# ewetioitde ilo t's
#  Tfgms
# cHamty n ninndetw oar attSn'lStnaf oslkeoo ukr
#
# iter:3099/40000 loss:3.1812219619750977
# generated sequence: W'aA uaNhr
#   h n hri  yyon
# sOewRg   il nh p y u  u
#  r feh Igg  s etruchlo,n t dnY
# m lhdtmEtkenUiuc iN
#
# iter:3199/40000 loss:3.149846076965332
# generated sequence: Wtow'r  orntI
# irgiotSojfztgkimh otg heg
# trs o ovtutht tyeuiro-mrleoes
# kw'tot drsrrnanC
# stetza hstvr
#
# iter:3299/40000 loss:3.1503777503967285
# generated sequence: Wt eoh'a lmagl Sw eoy inbwa klgee wfc tooctewetteb
# ahrtt e
#  nctswte idt
# a tyae u o  tsmzntdn y'' ytd
#
# iter:3399/40000 loss:3.1571121215820312
# generated sequence: WeCll tmacay laaasvfsaso t
# th sheTh anIilet  st'batyt
# Iogo
# ,avs s 'vyo ' aDaten
# l
# nluafnatariais
# e
#
# iter:3499/40000 loss:3.1756656169891357
# generated sequence: W ae  es,rr tyaIko lcte ywsdd s"
#   Fn uosixtnialptngo'ttdtrnn  glenlg yhd ulrlse n-leatuoIysht ors  r
#
# iter:3599/40000 loss:3.1808395385742188
# generated sequence: Wmd tsa bloy gsdloey
# ywhalntttiR lio
# 'ftvi de)lfnti e tecspd&asre)tih temi e eSsmtuteeyr.o y uohosnnh
#
# iter:3699/40000 loss:3.1666042804718018
# generated sequence: W irgnlhuLieaubLeng  iab
#  s
# on
# Dtttnu g aWtLle ht higel esu awebaeeb  ewhTmt lnievy rw i k
# ehe sSunt
#
# iter:3799/40000 loss:3.172450542449951
# generated sequence: Wbr wktr iit
# mr mgenl rlh enoeill?meheh me,soito aIx
# tefst who xeohsinhui
#  y"i iantIdt.bf,uroohe ac
#
# iter:3899/40000 loss:3.180816173553467
# generated sequence: Wlsnhower I utfthEn'hhtuu f r Ityyy lpostithnttH vihsnwidt  er rdoacdu.dio st
# Fr gdp eSao
#   ah e to h
#
# iter:3999/40000 loss:3.228325128555298
# generated sequence: WaSoce ,ht wrohdlmttfnhvsy o-y; oyimIuinSe teP uithlopueremLh mYsmtoo ymtyrfoit rgueshtatmwpcm
#  S  hr
#
# iter:4099/40000 loss:3.1543726921081543
# generated sequence: Web'oespmlr'aytgue'dg sebu uriAbv seTheo Bitkaalo y oa n torjle 'abhao
# ts le Cmkoltftg adl  o IbT
# o y
#
# iter:4199/40000 loss:3.1538329124450684
# generated sequence: Weom tieyriTnh
# e enacoeonc ayenfnlkl
# bos diosmrtoe so rwckyone ' dspoo mtsHicogIyrees ewiotkna tindi
#
#
# iter:4299/40000 loss:3.1560330390930176
# generated sequence: Wbasoeeyosahr
# hnsise
#  oedWei eo etts aoy,  tmI
#
#
#
# o
# tsIdl ouympnyeneaohuw
# shoh.ws
# odua
#   tv st
# lhim
#
# iter:4399/40000 loss:3.1602370738983154
# generated sequence: Wm
# di ieiewe aeuIl
#  maiea
# h',oooeietwolro ataa is
#  e
# e aoscayonsw furtll nlh
#  vley
# euaor  heedwain t
#
# iter:4499/40000 loss:3.1766505241394043
# generated sequence: Wsh
# dida a i
# s ioatIWipbe lmrr
# a dt
# tibghh iesmh
#  l ne n otaagedoe nnns wesiIprr tko tn
# tmonO llCrci
#
# iter:4599/40000 loss:3.177384614944458
# generated sequence: Wet ik ymmstf
# 'ooner,lmr'efaed uda h   N nurhlhotghugheol  dtmahtb
#
#    th eet .onebNrnf yl
# ,i  nk
#
# iter:4699/40000 loss:3.1926493644714355
# generated sequence: Wa  n eet sm'
# seey na wfe  shwa
# oehkg nohhlre  ' e,ssdea cd)amn,eter-eue ltost,iitygt  rr
# Iymt
# wn ss
#
# iter:4799/40000 loss:3.1590700149536133
# generated sequence: Wrdok
# dvu d mgeoeneese ee mhodL
# fetleoAhl hdu oiy htnaGogb rdtlnos Idsgi nlphhcfeteo s essNwIolktihbo
#
# iter:4899/40000 loss:3.1638505458831787
# generated sequence: Wt  eodear
#  oes  hnhoi
# aut  oydhos -
# lutu a nhtr're
# b anrns
# dida a,wie
# isy   p
#    owe e!snte oh  at
#
# iter:4999/40000 loss:3.195493459701538
# generated sequence: Wouu bh
# lnewv
#
# w oht mlla y ndit,paho d pn    wt
# soooi Slnmi x  dw eeoi 'ey svu leCostos  eie    n fr
#
# iter:5099/40000 loss:3.197941541671753
# generated sequence: Wyo odA
# f [no
# a
# no  t'odsiyr
# w aeYfrb bc dot
# i shaothehdwWyeoc: rhafst eoatde
#
#  rd'oteloihtiow gpwo
#
# iter:5199/40000 loss:3.1621696949005127
# generated sequence: Wflnocgr onn' th eeeugnonar nooa     wwlIiyc leBidi afB  A
#  ewbwerbhhwe ynen onw a hteoTlalw
# Bwebmyt,
#
# iter:5299/40000 loss:3.210494041442871
# generated sequence: WgI di-nn  hdi - wobd esovn
#
# efomh h m ait
# presdlfoaOwcaeevfd-nro roetao
# sI iHas as n  iufi
# a,heaaoyb
#
# iter:5399/40000 loss:3.2171359062194824
# generated sequence: Wbgenl ehfye y iLun  iaelirI  IifTau tanl  u,aotiotm ywudsr l y geyemma uonmn YoIbtfnooiab'yggvn wlie
#
# iter:5499/40000 loss:3.18682599067688
# generated sequence: Wtg enoaa   fiemlTt Srss. souv
#
# eeeeiwlasAo  ryhn
# iagtelhm ar oreeCes l rosnftodom  ama oecseevr oeos
#
# iter:5599/40000 loss:3.196277141571045
# generated sequence: WW
# n t eoh  it   o uteolmhc
# al d  uoieesrtyott enbre karueJizhrnytvasd
# 'slrithokiey,yoeoh ho    ordv
#
# iter:5699/40000 loss:3.1987297534942627
# generated sequence: W -'or
# w
# yolldo e'Ih n h m bneeaeytmretmtt mcleoL emlryotothIgeaee ltt-sea
# ufhuye ey.r
#  dHsrnfat'
# hd
#
# iter:5799/40000 loss:3.1803882122039795
# generated sequence: Woddre paatnrh'
# ooyideis i [sihl i i. A 'deo
# ear o' ea LsyrcnohEtnmtr satsaerdcse cneno
# hi ortGor 'd
#
# iter:5899/40000 loss:3.1492080688476562
# generated sequence: Wr toWupenoesnmiheeu edtu.oimih erksodlmlhien t ie
# ton rng , lhIflua
# oc l
# y a tlit b
# y k,n-erevo elr
#
# iter:5999/40000 loss:3.19502592086792
# generated sequence: W au at    o
# niekoysi arBi Snlleosmneh o
# yui raoentitUnunnueatnton m
# ylueaae irrkIuegaoeooant a
# ne rd
#
# iter:6099/40000 loss:3.1750619411468506
# generated sequence: Wt ntoegeos DI eome vhetgefmtndg  em eu  hkheye
# aakn  wrf!  taanIeltIsk o wo ir,Igmcloodv
# g'atoeahIi
#
# iter:6199/40000 loss:3.167362689971924
# generated sequence: Wnbrn fwyeitytgwte tdIh hri T"tdtbictrak'ayeeTos  nwNShre yrrottaoeh aoyaWinbuyaasop eah h wInah tcgo
#
# iter:6299/40000 loss:3.174288034439087
# generated sequence: WengTnriogalnonnao  oeevoyo atlrel
# yeg nieoae lekllimna onlnf  e
# owfeiea oor eAc euoo afh so onsbWl
#
# iter:6399/40000 loss:3.2094693183898926
# generated sequence: Wcedhfv adr tat eitsvehurese ap g h niveaeou'hkn
# h  hsl le
#  t iiakw inhtm Ihe
# nnue,deese t m w eml ru
#
# iter:6499/40000 loss:3.283649444580078
# generated sequence: Wld yaus ohoothators nakiv e
# nows el"n u eY eo o'eyoost,
# oef -o u'
# tk cdoosey ,usd
# oIlr. ew oonas r,a
#
# iter:6599/40000 loss:3.4227044582366943
# generated sequence: W u  O nmoa i r'nr enmuat
# wn
#  Hi
#
# a ntlk swh
# ib aWA wg  h"kbfd  In yaeudkglreosaneo5hivnmyst
#
# iter:6699/40000 loss:3.3655812740325928
# generated sequence: WR eh
# edanuhe,
# ee  fueIevy ooiiae nrfoerpriiTwe (e.eodatwnhue  ov
# ,I
# en Iom lhhmqwic h
# ee-m
# tv ee yms
#
# iter:6799/40000 loss:3.216187000274658
# generated sequence: W rwlnIW
# o  ednd esi ahsn oIhi h uh geWad nt t  s srksueiamao wsuo
# ng ih
#  lin'ial nupoaI himsi snf
# ln
#
# iter:6899/40000 loss:3.1607556343078613
# generated sequence: Wrlmoyne O lensfno gh  nwstaai
# tdo dbt wr eoReroseo s nehooe'rettrnr  nyesl ' rprrtu 3sig'ootitna
# sCu
#
# iter:6999/40000 loss:3.1550772190093994
# generated sequence: W de   s uebarltY  s nt CcihhI d aspiu  udYsatlshodts Pmaies ' ihAtN s a nbi ae be'   enots
# mkfpnsrl
#
# iter:7099/40000 loss:3.1648974418640137
# generated sequence: Wcntri  l nimrnbno
# 'dd
# oprnhdDg dn lsiassdy   el  u hayr lo ir seone n
# s?Be   oI ar atd"LetadIu s
# g
#
# iter:7199/40000 loss:3.21040940284729
# generated sequence: W m rkagSIkdv cfwnealInhl"i e o
# de v  hdw scntt   nsi h tmum
# fo I bUIsean oina  ydr yaunbhiav
# s i kdr
#
# iter:7299/40000 loss:3.160325527191162
# generated sequence: Wt
# na ao vieWh   slnap 'hbb vlhvbd'
# el  hniooe p,i hew l>B
# j rt lh
# l arplo
#  mearp Gtsopceeuia t lm
#
# iter:7399/40000 loss:3.18214750289917
# generated sequence: Wvr
# sInewhenmetn
# flr  ' dumtryit l l rlIairhhorzo'iroadthtkmr
# O
# uoTIh woom yw n
# iolh
# eIowMtfe ut
# t
#
# iter:7499/40000 loss:3.158842086791992
# generated sequence: WoTg,mecgsehlgmA hnwh leend Iagh iakhn me:hofta iifeit t  eoswo  oo ec'h 's tSanp a o  rBksbgo parnn
#
# iter:7599/40000 loss:3.2005162239074707
# generated sequence: Wnta a-ebhselsyeoieAydr e wa
#  tg yseeb(umrunnindu'w   e aj nliaail'rlaw'os eulicya A,yIc mrttI  w  Tw
#
# iter:7699/40000 loss:3.1476221084594727
# generated sequence: Wos.eto steoonowulsvo y oThloiw oactishe ent laon tgtw n'a l? Atso vg    eompnmlt So ethw
# ee ditaata
#
# iter:7799/40000 loss:3.158043146133423
# generated sequence: W g d,ntkTi*rsl nehdi vtosrse
# o  wce egtn eawtocy k a lda eo dedn yvensnnladhg vr eno' ee ag  Rr otWo
#
# iter:7899/40000 loss:3.153343677520752
# generated sequence: Wnthnhuntttr toear
# ouitso p uuru
# iliyn wgma  r
#  onv h tlIeeu a evkIru   oieyrenn lt Tm hDochnu
# s tds
#
# iter:7999/40000 loss:3.159501075744629
# generated sequence: W u ans r
# nddhefaP  rsh
#  lidm esiitnledris
# nrHetht InvIy= sGrhootiorkv  etacahd lo ne hu tlnf n anrgo
#
# iter:8099/40000 loss:3.1760478019714355
# generated sequence: Wrolnn otkib
# n
# o  yg
# t khldtsnp leiI hntsiOcrres
# utA  jmoauw hn ohert inefh ouak  an bemwfrt
# ebalonn
#
#
# iter:8199/40000 loss:3.1493141651153564
# generated sequence: Wi
# eyeea
# cho'rineioue dsmuIyJseabwieheoats a
# g
# e phmeBo opir v e
#  Gmsrgnt ovno
#
#  ge hhrefuOyem
# n 'e t
#
# iter:8299/40000 loss:3.145212411880493
# generated sequence: We oemina
#
#  a sy mGl fdtma n onoehhisodddeMeat
#  lais
# ikioa.ea nkW
# dmdaerae TTnoeintwa  ttrstu hceM ig
#
# iter:8399/40000 loss:3.1789610385894775
# generated sequence: Wdrr
# meo d w rn k
#  hl rforiyaarhhninlrihaehti
# yoi uep
# isdaawan h wa F ywhrlau thmiaC
# heraa
# nunrs 'hg
#
# iter:8499/40000 loss:3.165990114212036
# generated sequence: Wtrt,enn aoodpS  d bu   eoydaton s vy   fde 'o SeaueetIas,o nn m uha
#
# whad andc leerE"np rs
# rmu  Y i
#
# iter:8599/40000 loss:3.1392476558685303
# generated sequence: WPthei d aea  dimnyiy C n tOhet a putm'  l eiiosos HhnW'ne'o
# r"d ii'btvykeurr
# inh rth  tth C y emorln
#
# iter:8699/40000 loss:3.1639983654022217
# generated sequence: Wt,yt eoPcsn' tis' a" omuayonadutnhhyisl
# n
# jot e edtB aole  b dr l ah
# oaeSnwy hueu leuyl " r
# Imoeed
#
# iter:8799/40000 loss:3.202698230743408
# generated sequence: Wfo tstoe ut p e b athggdwoaI  dt  t ogc ht wnt'upwtrdIY .vc moot'y ehfa i
# fTmbabdeto ShdnltyoIduedoo
#
# iter:8899/40000 loss:3.1529181003570557
# generated sequence: Wmh   a
# eeaar pUu lhoaes eotn hdegdy ur   eag
# vuetl hi f   eWtebsoael cm.arerEo aa e
# 'ndneahatrd
# iIwn
#
# iter:8999/40000 loss:3.167534112930298
# generated sequence: Wg biuu gl i'i n'adn  e nTlbdeoipl noh g raeh tntcsieteoI dotualrrn st    me gt e nroctle nitsge oert
#
# iter:9099/40000 loss:3.164529323577881
# generated sequence: Worsa uowskaowono hes
#  ussoawu'a nueiGtraohme hb'
# ssn d
# s
# agm me
#  oovt ehluehaoat rf tao whe
#  g o
# fp
#
# iter:9199/40000 loss:3.17275333404541
# generated sequence: Wetoe eeiahee IoONmePdrb aaenieo bg nltnnamnst
# esmyu stshe eedouf uuriWnonn?T"on eeni yedael
# tt hei o
#
# iter:9299/40000 loss:3.1902873516082764
# generated sequence: WsYo eb esae oo
# o
# d h o chny
#
# gnr, eieed,ret
# lAoee yAsa'
#  f I wea t n
# 'fnnra h t yna
# hn
#  lny  deo o
#
# iter:9399/40000 loss:3.1541519165039062
# generated sequence: Wa eaUi n hyng'
# u
# eiv mylroMp e ot
# Sootoar   f l"urgoo LyI
# g ut
# -r Io
# w' eanbbe?dwWe
# t t
# efSandfise
#
# iter:9499/40000 loss:3.186253786087036
# generated sequence: Wsv l  lo rwhoe'nrrennIrrrknguore
# oinhk l  eoe or a snhro
# aitlecestmktlIef eonith I ab' 'At
# C ebo
# oeg
#
# iter:9599/40000 loss:3.2246687412261963
# generated sequence: Wmo lr,rc'n o unRiasr3 orsnenr
#   iw d bn al u ReH t loen oik'e
# i
# unlnoI  oafi
# oe ap i ,fhwoinwltcSO
#
# iter:9699/40000 loss:3.1728248596191406
# generated sequence: W
#  thml yigandero vvnotmnmfgad"
# nsoatofl
# Iawabb feb'"i  t' ntoettb,
# loc uroa
# oedn
# mculhei  nu botu st
#
# iter:9799/40000 loss:3.263544797897339
# generated sequence: WesoYnu  laro  YIWSaorvsbranooh'dsva rta
# iur,eehre onai iaran onrweioodh?ei
# ChoresCleayetulsidipae ft
#
# iter:9899/40000 loss:3.1387574672698975
# generated sequence: WufnIubh)dddecnsy
# eldcueaotanlne r ap uynedeeenlBa ob mbelt  am ytiS ii d ad uiTI mltaysh  nt  e r
# h
#
# iter:9999/40000 loss:3.19997239112854
# generated sequence: WtegIknheayaw o
#  Vse is o kdrenom pk  tthu
# thue hyu dh lkuaf -
# shlm osdc t ere
#  n  ifcaiiYb entudm
# ao
#
# iter:10099/40000 loss:3.155646324157715
# generated sequence: Witgomeedef'ey  hraltns  hliae jy  vtatfI yoelTjwtbaivtoSroe
#
# ttTw
# eIkc inaeii  na oo ,t m s ciistd
#
# iter:10199/40000 loss:3.185875177383423
# generated sequence: W
# -ee'i
# eismiv
# u ht
# uo ma sag  y l louBc t
# u
# dosou-ia ielo
# s Se  nisTods"t  a
# jarhoien"ab , t ot
# pcna
#
# iter:10299/40000 loss:3.177720785140991
# generated sequence: WnowsoeattlotheA  ynwsl s'hy hh tStfdocnersrrv   U g
# u  wmi wLn n ywtutAeei a ni nrcelnh
# ns"at e Ibn
#
# iter:10399/40000 loss:3.1750378608703613
# generated sequence: WeBo  na
# a'ta kartnnrset
#  ota ri enunieTedeev)aoatslaammewomile  b - hwegtaNtecnru!rA  en    iloaoah'
#
# iter:10499/40000 loss:3.144167184829712
# generated sequence: Wtisol dlaessa egDt ayirn,afa sf
#
# oe  'sn yu la de'Treofttieot ertodteuipoo
# thtl   urd arnNwde's hd
#
# iter:10599/40000 loss:3.1669180393218994
# generated sequence: W''e
# vte n tm
# ' o or leilsh faoob rone  o ifyOm
#  n ht?lan
# ngiblnIlac YstartgOuk
# l retls I  tr   e
#
# iter:10699/40000 loss:3.1545634269714355
# generated sequence: W n  i lHrl
# sott[ er teto yNwdrnhBc ly enl
# rw dd hoit
#
# renrlno
# aif ,wmotrf'rrvaw
#  oyhyyloud taekl
# d h
#
# iter:10799/40000 loss:3.1883671283721924
# generated sequence: W  iytod ette tnhteN i tsoas mmydtyue st
# kso  ectpniw toeeceih  ahntsoaebet  Hyoa ustupnmft eimol gnt
#
# iter:10899/40000 loss:3.2072198390960693
# generated sequence: Wme
# er aonnonnto
#  le
#  oe  gbcyow ee(I r  aanwko eo moeteGa eomd neb sb h
# t ia ibdoadrnt
# Bo m sy sdaB
#
# iter:10999/40000 loss:3.17775297164917
# generated sequence: Wpom
# dwwonprw ersAhBDll erd,vw hh r  t owdto nrotp eyhv
# ir heei-glig,iTawNaadg  o
#   tmhatI
# oP- se ep
#
# iter:11099/40000 loss:3.245164155960083
# generated sequence: W'inn t  l-suoor are
# ogod n l  mioen r atr l
# r noabyoeo eis  an
#
# ese e e wr h rrIas
#  nc  mItp ar p o
#
# iter:11199/40000 loss:3.171869993209839
# generated sequence: W e -h m  b il i  da fee uri,ao ne vlc tt
# h g uaul afo.ehhikn pw ye
# s wmsueonCtwulylweaa unita odo
#
#
# iter:11299/40000 loss:3.1968185901641846
# generated sequence: Woar ned brrl itb ro y
# ait
# Isur e roomse rnntnhF
# Wrsoaeatsh)nosog woaAytffurvltNttk  hih  tsp ro
# sl y
#
# iter:11399/40000 loss:3.2038891315460205
# generated sequence: Walnh  a
# lI ee
# el n kalkk ioe  iceas ruuetotsea mMuo nei Re b
# . itlnp t-  a  amoT o ec4leYe Irko
# eb
#
# iter:11499/40000 loss:3.158012628555298
# generated sequence: Wn ihuiey ihigf u
# p
#
# owaurkanfh e
# erh eotoeinieo fd   u o T  ekhw h'uomf meybbleyuwfiviu tyyrien
#
# iter:11599/40000 loss:3.1692051887512207
# generated sequence: Wl
# eb odm Ite a,isaswr fei i rg. nmhn l  hten onnamlne sw mi ysmt
# niltot taeeo  b
#  ikr ar
# Ay teahehbr
#
# iter:11699/40000 loss:3.1547985076904297
# generated sequence: Wwhpetwne't
# hoi anil iyibjl   heoaa' a hTrtfan
# 'r  vt  diFhenhvto e'ilFf
# t "hte ilc d
#  pewmaow-whTl
#
# iter:11799/40000 loss:3.156423807144165
# generated sequence: Wclt arntioe-toliwT n'  n eo
#  hyti yy
# u  fv ece
# rt   yentP '  dehnmdrt' tF a eae
# eggd eo !s szeiI
#
# iter:11899/40000 loss:3.1231601238250732
# generated sequence: WhToerg  e'tlwdsoeSD c st
# omOaynMfor o sc  ea o  ayt oet,iiyduhhtT t nisvtag  ko,eol t eT eonno e ye

# %% [markdown]
# Stopped the program at 11899 iterations, could not get to less than 3.1 loss.

# %% [markdown]
# #### Training Loss Curve

# %%
items = [ele.item() for ele in all_losses] 
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(items)
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
