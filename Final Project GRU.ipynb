# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./trainlyrics.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 106526624
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of rock lyrics.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        self.num_layers = 4
        
        self.rnn = nn.GRU(self.input_size, self.hidden_size, num_layers=self.num_layers, dropout=0.2)
        self.linear = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        output, hidden = self.rnn(input, hidden)
        output = self.linear(output)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(self.num_layers, self.hidden_size).to(device) #made into a 2d tensor. 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (rnn): GRU(100, 100, num_layers=4, dropout=0.2)
#   (linear): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
# NOTE: You may reduce the number of training iterations if the training takes long.
iters       = 30000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.001) #increased learning rate from 0.001 to 0.01
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/30000 loss:3.385291576385498
# generated sequence: W1Pvt rs :a'lreo  tee
# ai
# rvhN  sma
# r nyryatoeydocoero
#
#  w ue dwXt bmytknue,
# tf  a olwwseearwttd
# rnvt
#
# iter:199/30000 loss:3.1886072158813477
# generated sequence: Wdtekt lis(css oowittdsh dntnBo
# cal  soannavmate
#  on nutlwo1AnmvogF  yaaohodrlse
# f[u
# uspurf evesos wm
#
# iter:299/30000 loss:3.153202772140503
# generated sequence: Watetbacjid eicmol s eeeetoerechnuo h algi ' eu s nirtomel gioii
# unilgadaehg ueoe f
# reawsavefatamnoe
#
# iter:399/30000 loss:3.1506154537200928
# generated sequence: Wjtaaivtoree i
# oitneenierawtC e e ,u s w  enwnedeswi Ieikeyu hloitlnydXd eh geb h 'n,odloptd vtdab ea
#
# iter:499/30000 loss:3.1363775730133057
# generated sequence: W c  sma
#   n un
# yhaysasentw el Ar
#  e,o aowuetme
# oahoaow lhhl  rd ef
# ehweece sooaopnmsgluhwmelwaeheeir
#
# iter:599/30000 loss:3.1994431018829346
# generated sequence: Wkia hlhaerg soaa s lf ekLeohotohr oe  oah  ,ko e hcatkTAtySyeu '   so dtrndsatveTt rtebewo nenylkeak
#
# iter:699/30000 loss:3.1902544498443604
# generated sequence: We *ftgs
# g
#  hua v uaa.goo ih
# ueoeie dhdfGa Ar t   uuaobihptn
# ipoi v , evohml oyoh , ot  ihuelt enon s
#
# iter:799/30000 loss:3.176694631576538
# generated sequence: Welas
# mfony hlmdweread n l' n m
# ueohnt  ase,yh hm pontaW
# aini  eit  u lBrodd ca m aeguoh ptr  ah aow
#
#
# iter:899/30000 loss:3.1637065410614014
# generated sequence: W feudl
# eess
# o  ayiohrnfhA e? ealIv'eosiAao us, ti  mc odsh'dh algYrnitruomsasoeu
# cen
# ''
#  t uut ypr l
#
# iter:999/30000 loss:3.149416208267212
# generated sequence: Wumyokruu tmi
# rnateshleiwt ted  secBeiwsIt aesI)tymtclteklth tiLnnlooemafs
# lie
# gkhw  ooohnuuBwasyidgn
#
# iter:1099/30000 loss:3.1722524166107178
# generated sequence: We hyCaiRr sod rosyyrh hnsy
# t nfhauh oo Ata
# yfaotSdaaniuetnevhoer
# utl aue'b eiui
# tdrowhe merm  lorrc
#
# iter:1199/30000 loss:3.1789560317993164
# generated sequence: W
# veiimeidOd
# tlfhrd
# tcU? h-lSerevuety   uhodi alnomutgnnsh
#   vr tnel
# wosraoct tci
# e whef tela
# egn
#
# iter:1299/30000 loss:3.1593258380889893
# generated sequence: W?h hs hl rgrdl
#  yr i  eO iab immoeelberoAttIt,Iorogthoi hapnityron
#  ] iseAo
# lm,n mu  ouoow
# nNoie ?eI
#
# iter:1399/30000 loss:3.182335138320923
# generated sequence: Wptrdfanes wa eiuPnm rt oa nocul u huoo
# sooWenm tnnoosSnheauae onuoeo(t  rookieniaermdrkhy y reovew a
#
# iter:1499/30000 loss:3.0812435150146484
# generated sequence: W
# m ret hdr'natial n'k m'n ns f,I m p
# sf m c  rirl'tagowektrw coneeenhe Iwums dabgkteu
# nme jnrtak w
#
# iter:1599/30000 loss:2.8897345066070557
# generated sequence: Wd trNe
# Ohaana faee
# WYd'jtlisnhigr ytl
# 0tarhd woyrg oijnrel thnd'r iseol weAtet lm ws sreitapt than m
#
# iter:1699/30000 loss:2.719067335128784
# generated sequence: Weoueyr cgimsr me
# I'. cgmer lon gy rane aneun wet an uule anerdys
# jhe'stse
# AustoI Iogw keovowdew
# e lh
#
# iter:1799/30000 loss:2.616597890853882
# generated sequence: Wy bob staln
# Yon tori
# id
# She fof horleasiulim to fat. holo rrit unatwn ihk lond lotalen sot win yon e
#
# iter:1899/30000 loss:2.635943651199341
# generated sequence: Weerhnr hhoauss
# Sonoy ir
# modir chac Houn bonvacg tivg, ine
#
# "Iye t an cots
# Arrl wind cer himsath i me
#
# iter:1999/30000 loss:2.548203945159912
# generated sequence: W al al tht e's bon i theg re chse
# Mo.e
# A tovy an bone sov keev noge'gg mof at tougote motged, dotrop
#
# iter:2099/30000 loss:2.530697822570801
# generated sequence: W afd garte'sile titge
# Weart
# Aun i nn
# :yas i
# Ir er I mote,
#
# Htero se oe pum an tiury
# Suwo cote Iulet
#
# iter:2199/30000 loss:2.47279691696167
# generated sequence: We goyf
# bayd we yeerely
# (n pos't sitk myamr i tU thin foryt than'l,f
# An Ileagy heTe bn baves hadeey w
#
# iter:2299/30000 loss:2.542384386062622
# generated sequence: Wumt nome tDer loud'nle ol sone'dht -I maml unls ish bav cfe tishingr hher tknerke mai reanyn want a
#
# iter:2399/30000 loss:2.411527156829834
# generated sequence: W"xnl ius un't rose on onnt
# Bande
#
# Ands want I be dhereont youp It miul
# He laot a wheave,et ti
# You wa
#
# iter:2499/30000 loss:2.4066710472106934
# generated sequence: Wroodt
# I'c handot cot int a"Fobm to maydane reab bong
# Thiop I the cory Ie
# !od
# Bog -She khack us' oom
#
# iter:2599/30000 loss:2.31095552444458
# generated sequence: Wan
# Yeue on no nol ofer mige lail? you fite leese mene san
# Pirl, o nope
# Ish giy,eody
# Bet you to chene
#
# iter:2699/30000 loss:2.351572275161743
# generated sequence: Wib
# mithe
# I faskasrind ar wake
# Thoas youg thave o chtat, I youn I
#
# I dikesan jtonse what noun't thos
#
# iter:2799/30000 loss:2.3003838062286377
# generated sequence: Wen
# I lir"Wane  thioneet an co the pot thaBs you ror biat
# Wohe
# leat bicave
# The dion wiyn
# whon womon f
#
# iter:2899/30000 loss:2.309587001800537
# generated sequence: W,, thear afe-taBg hounde githy
# Fovl
# Mroul, my thy
# The copre ul ture, wout't,
# She ryanshie
#
# Wipd kius
#
# iter:2999/30000 loss:2.2476470470428467
# generated sequence: Warp thew you howt a vint
# a lonle kin'
#
# WOt sithede lun
# Yuw in andr cadet bleige
# O ovele eude
# zime t
#
# iter:3099/30000 loss:2.2356021404266357
# generated sequence: W\ wi6g renl wuvy you fop ave
# W]t"You nouvew eme lever
# I un jyer i hes'ring Lime bldave
# Con is nonl s
#
# iter:3199/30000 loss:2.250615358352661
# generated sequence: Wbs the langh,
# Whisinhang I upover
# A mist antm som oft I fink
# Syee I pit pame nletore, by ir wtrowe m
#
# iter:3299/30000 loss:2.2716939449310303
# generated sequence: Wtiuh you kay'sle go skeanletht in make
# Ye fa dear to cound on Awer wror to wtiky
# Lume thamgoch
# AD wh
#
# iter:3399/30000 loss:2.25473952293396
# generated sequence: Wien
# 'up'n'n macke in nout noir cnald out reah huOt iw laed you byr s hade led the the and si
# Thiths
#
# iter:3499/30000 loss:2.1885550022125244
# generated sequence: W leld thes thet bt.rer you, wongO
# Its Dind thel is beying i I kive IArf soon to 'hecr
#
# (And tirl the
#
# iter:3599/30000 loss:2.18674635887146
# generated sequence: WFer
# I've andmer mach
# Wing mibe at in it enere
# My |astetne by oiphss it'm
# domiok can deleve as to
# ToO
#
# iter:3699/30000 loss:2.1398091316223145
# generated sequence: Wear at ciaud yreeom
# jut hatt thin' thauses you saer
# Oxg I citsrin'ut lomisn) to ju faur
# you nos gle
#
# iter:3799/30000 loss:2.1356117725372314
# generated sequence: Woald
# I wound talk tho slald you rean
# ones somen.
# Euss to fe.l fa waslid to gonot
# darg's'd co goundr
#
# iter:3899/30000 loss:2.1405646800994873
# generated sequence: Wond dhos fase
# te mous you's Hom
# Wherel gagis nof
#
# Iphon mom our i ghiz
# Shet ming on f bead unlser C
#
# iter:3999/30000 loss:2.1774580478668213
# generated sequence: Wos and a was all
# Bneade is lones you itg baken sime
# I-beed whe and the juke baghow
# Bomn baerin'r ray
#
# iter:4099/30000 loss:2.124232769012451
# generated sequence: W
# oh the ingus wones ik feigcnadt raashet he rush
# Fle the fel dhome theun trey we in the me sist a ru
#
# iter:4199/30000 loss:2.1228811740875244
# generated sequence: W_r an, you i-Seedtos you lefw toO hror foht
# In you ge by suKd me be ap tirl ding fal
# Wy leatiy the a
#
# iter:4299/30000 loss:2.097566843032837
# generated sequence: W]e I nithcan,
#
# To Miss
# OCaadt.`s five be the seet
# Ye be ov,oup the
# Ye goal'be to fart
# I indive. year
#
# iter:4399/30000 loss:2.08195161819458
# generated sequence: WTlee me coight, shos hmommind rind the saald
# These he that wat to jnw
# What your domefv banm any Your
#
# iter:4499/30000 loss:2.076850175857544
# generated sequence: Wanlonn fin't woob intaegh in a wtece
# Wume fash tooges men wrande ture that thithy in' ald apm touth
#
#
# iter:4599/30000 loss:2.1094553470611572
# generated sequence: WaIt cafp to to me be dund
# Lojh aOll nitp'ss
# Seewhing hoth ip our mutt me
# 'hma sallunle
# An'r lide ha
#
# iter:4699/30000 loss:2.0620644092559814
# generated sequence: Wyel. anlnt tha
# It sonc
# And at do thas howsad deel
# "[Cleching frorher wike., deas
# yus I Some treed hi
#
# iter:4799/30000 loss:2.0603811740875244
# generated sequence: Wkot dion
# The on The cnade,
# To let vine
# I'mseciy find funeing,t tin
# bruke ufory nowf a pain wiins me
#
#
# iter:4899/30000 loss:2.0636751651763916
# generated sequence: Wnrel trund
# I sick I damle betqlack by
# Daftcuse the to me befy cepes wle of you hes I bom and wirtir
#
#
# iter:4999/30000 loss:1.9975364208221436
# generated sequence: W she be
# For Won'out's siwtle,
# Tarlin sade -'m tom it wet tho.r nemf of tot thit'm you hep svoc
# love
#
# iter:5099/30000 loss:2.0089938640594482
# generated sequence: Wane byal the wtrrorfen
# Alvytirnce
# Don't I walldes you'l natt ceat A baper fadey anlind, dipled
# (Goll
#
# iter:5199/30000 loss:1.9976991415023804
# generated sequence: W m by mile
# pald in Il the bessle the ware monir't git cold?
#
# Iw the two co it me and or ande Jeupd m
#
# iter:5299/30000 loss:2.0611255168914795
# generated sequence: W in chey
# 'pe keech mafys and two'n'a grow oher"
# Showe.R. gone
# ar, it me'pe? tro a der,y youren.
# or
#
# iter:5399/30000 loss:2.007436990737915
# generated sequence: Wo,'d hrigt twhe mis asAn
# I won't hiy toes as mine
#
# I wackicist heard but alt homevy onay
# Raas
# I waI
#
# iter:5499/30000 loss:2.0174834728240967
# generated sequence: W,s of"As I lot mon
# you'rin' they how lord the of
# Deaghise it so man
# I we the nug papy of of me fived
#
# iter:5599/30000 loss:1.9782121181488037
# generated sequence: W3se prold of to ,
#
# Wising hone tey'p a chaoidessing
# And wiwht of theeft
# And the faiso wrake the so
#
#
# iter:5699/30000 loss:2.0092461109161377
# generated sequence: WKe the hoor) attaming, be
# Sould beall with but to got I you
# He've unly do oneasfing me
# rout me fon't
#
# iter:5799/30000 loss:1.9306010007858276
# generated sequence: Weitgin'
# Eave thote chay
# Yeag yew me befe will o
# Dulking to gatar
# And slare might of coming tiogun'ds
#
# iter:5899/30000 loss:1.991864562034607
# generated sequence: Wern now then
# ["As e-crongh
# Hannideingat feakight
# All so lore whond, hill out of to suke
# Neul'r holly
#
# iter:5999/30000 loss:2.0276455879211426
# generated sequence: Wrering it a rover oud herer asainige
#
# So hive levgang, then.ed
# wefime on'rle spant to lulester
# Mnast
#
# iter:6099/30000 loss:1.9604500532150269
# generated sequence: Where ap,n and bont,r aig juke
#
# Inter I'm hrand I con you crehegent ant Muce
# In the good fee your mac
#
# iter:6199/30000 loss:2.0128509998321533
# generated sequence: W?
# The move, fay stunds
# Bur you, Fnoul in in a.ona ever
# Sae get me hert aht to basy we bes as a hicl
#
#
# iter:6299/30000 loss:1.9683107137680054
# generated sequence: Wis' shings, by
# chorly live evow buy you
# And doa'm me dist med am of wond
# The erey to you nore madnot
#
# iter:6399/30000 loss:2.059014081954956
# generated sequence: WEd yever that in' chac
# tiit whow goe in they
# You're up dabe I'm
# Griegs teld don's soull shole dege
#
# iter:6499/30000 loss:1.953266978263855
# generated sequence: Wais sun but in cuise ofy dould herigh
# Sheing
# And castaan.ives
# Oh aln sord tru5pister plary that cuca
#
# iter:6599/30000 loss:1.9570890665054321
# generated sequence: W harnter
# I I bach I'me I'd posnle chey.
#
# Whiedteng your how man
# Tell she watictky?
# aar the thites gu
#
# iter:6699/30000 loss:1.977222204208374
# generated sequence: W, so ligcks think
# the ahe, arind
# So may though
# And youlem that's it it dight of to hlo
# ""Oh ea, hot
#
# iter:6799/30000 loss:1.9141985177993774
# generated sequence: Where no don't wloul gone?, see be I pupsathing
# Lefhst haso
# "Wh eapay what it my
# Way,, On rnaznise
# wa
#
# iter:6899/30000 loss:1.8997538089752197
# generated sequence: Whe to what fleesf"
# Feeees ap evwaas, shous, cher
# And alIrylllehasher I cworp abny bain
# Do toone dedi
#
# iter:6999/30000 loss:1.9616928100585938
# generated sequence: Wain
# Chorinu get you anging
# You takilvimedt of toir out to he palk
# In dould of pre-witht a ried qee
# 1
#
# iter:7099/30000 loss:1.8892207145690918
# generated sequence: W
# (A
# But the gis withs for twrine
# Where As I whet yuw evifs fhe I tume the but yewlering
# All when to
#
# iter:7199/30000 loss:1.9108338356018066
# generated sequence: Wuys
# I delless dire seet leah in af wordt my than
# I're one all by net elsese's we and toon dead
# it'g
#
# iter:7299/30000 loss:2.014746904373169
# generated sequence: Wor the tird a wrow mapense flite
#
# When llal his can't come thightun goa for the caytan's bwant
# Sreat
#
# iter:7399/30000 loss:1.9203453063964844
# generated sequence: W-there roel, is's gonedt on the we lyed hroming dade cun wuty
# Onfy even keenssice
# So swigh ans deeid
#
# iter:7499/30000 loss:1.9414347410202026
# generated sequence: Wa-to rnowsy
# i what can fromed of at your,
#
# I wall, shroulndn's dave
# But don't your wong to
# steming
#
# iter:7599/30000 loss:1.8883345127105713
# generated sequence: Way heen it a pas
# Bare memin-juuke."
# "Weel roll! no, by monee wenack
# Jgfead Caod
# Shan fooher hacrs
# I
#
# iter:7699/30000 loss:1.9170401096343994
# generated sequence: Wis gone ourth evind prow,
# Whis gone faming to by wa farade momelicly
# I hop and thum I'll?'t Waf to
#
# iter:7799/30000 loss:1.9409267902374268
# generated sequence: Who kour-me heach is hell rew you ne
# When you male me Coll so fleeter
# It's withid of the cade,nly on,
#
# iter:7899/30000 loss:1.88170325756073
# generated sequence: W.wordss in
# I can't kobe back all this ind of hear, love Will tried for to oye my but her, I'm try,
# W
#
# iter:7999/30000 loss:1.895443320274353
# generated sequence: Werla nor they witesabd to liell you can't joqgain re!ms to me a back of I'll list that you am
#
# What
#
# iter:8099/30000 loss:1.913135051727295
# generated sequence: Whell no in the as You hnaet thiels
# herr made oh One to skax her they unt thather kain
# Whey aloogs go
#
# iter:8199/30000 loss:1.92864191532135
# generated sequence: Whet the daik
# A laare breald yout nead
# Pairn
# Tume you? o2-;ourp hert this of they with to my moa
# so w
#
# iter:8299/30000 loss:1.8741507530212402
# generated sequence: We shout
#
# For the stak
# The cast's darla
# OhS honel dronging mine mntuyce.?
# Rok the suig
#
# I've
# But naka
#
# iter:8399/30000 loss:1.8749154806137085
# generated sequence: Wun and Mongy i so manmin
# Weling, no sippe afe fatiint
# Theis ill the yoar say and swale me stop crrea
#
# iter:8499/30000 loss:1.8714542388916016
# generated sequence: Wain good to when if best rarlide
# (You altiire, yen you
# You do eeping liel
# We feition,
# I'll yegev, do
#
# iter:8599/30000 loss:1.879943609237671
# generated sequence: Wke'd the samed
# (Caom awh strikinger you geth gost the the plapers on hold
# vame.s hight hever junrs
#
#
#
# iter:8699/30000 loss:1.9365012645721436
# generated sequence: We foor when
# Sown his take onu eataal the onets cher prease on som
# Timy and dicktul you kabe your cal
#
# iter:8799/30000 loss:1.8283255100250244
# generated sequence: When on, Tole to sourife
# I keey, treering I dit don mney they boll
# It becose Meore Nour you to cral t
#
# iter:8899/30000 loss:1.8922574520111084
# generated sequence: W.d a chise be strrer
# 1Jush
# it to be quay freade
# .reckt ramit Free hand
# And eus be a truth is chowepy
#
# iter:8999/30000 loss:1.8601796627044678
# generated sequence: Wh as ching a pongos we't want
# Cole tr-prmoned garned
# Muttoh it to never what onn the my
# (Tcorm take
#
# iter:9099/30000 loss:1.8693782091140747
# generated sequence: Whes now
# Ne po pacerfen
# If than till freos to koos
# your for a be dear
# Und the can't so pragandys pavy
#
# iter:9199/30000 loss:1.8830082416534424
# generated sequence: What do axay'
#
# You seong in theyre
# Thames me a gut is daves mac, if read
# On't you lotpil't like do wa
#
# iter:9299/30000 loss:1.8610856533050537
# generated sequence: Winu down
# Faikee the gos tay apay
# Whosn us fortn anl foart)
# Of I need shot from me some of awan
# It't
#
# iter:9399/30000 loss:1.8655532598495483
# generated sequence: Way?
# Look you're coumtion
# Coll you
#
# Wants to bets be bight noon-no preate, decaall
# No want the can't
#
# iter:9499/30000 loss:1.8682198524475098
# generated sequence: Whhiee no mey
# Blae he dealming is fore"
# "[-VO-Vhour)
# Dre will sturgunet everyy holv up goand
# And of u
#
# iter:9599/30000 loss:1.8736274242401123
# generated sequence: Win. (Bnepsathines
# Oh agay b
# You're to bay neving outnaim havs me tery
# Whoy befy fik big thak gill me
#
# iter:9699/30000 loss:1.8547126054763794
# generated sequence: W to masty now it's you wilf be?s.
# No turrosy
# Liky jletter the wes my
# anweepart, ohs, and gorno to th
#
# iter:9799/30000 loss:1.839228630065918
# generated sequence: W hearthyd her
# Whee me wime bun anlyfince listent
# Fore noth to be tart
# Bit is ruveuse
# Then the fast m
#
# iter:9899/30000 loss:1.873246669769287
# generated sequence: Wet you're hnow,
# So gonn all be ibod our hever
# We've jo lovk, the wis digned light
#
# Ever gonnin muve
#
# iter:9999/30000 loss:1.8326624631881714
# generated sequence: Wh no
# And o mot havd nog to land
# Bef no gow goall leethen that I for kel the shis afensaseds loves fe
#
# iter:10099/30000 loss:1.8884904384613037
# generated sequence: Wept ?haiy
#
# Herody
# Two you to staas you comide to uo
# Hickt acazing
# 'n, time ove.
#
# Why no Kistle inno
#
#
# iter:10199/30000 loss:1.871795415878296
# generated sequence: Whing
# And the can I sways through whet you can on how boch/ing
#
# 1h life that of he come it
# Too, nenm
#
# iter:10299/30000 loss:1.8833036422729492
# generated sequence: Way what to tadcan dedeh of He0
# Will warpy you kore feome when woill To peel fry drefe
# He deings the
#
# iter:10399/30000 loss:1.8573733568191528
# generated sequence: WGet't goand let mit
# My exy bybere castich it I lablit,
# eo seed of the won't got
# Want it's my but the
#
# iter:10499/30000 loss:1.8252874612808228
# generated sequence: WwWly we feel you
# Nod aftlem is the can
# lopt you worldaying torm so.
# in apery I stall pleal
# Sasfy
# The
#
# iter:10599/30000 loss:1.8306208848953247
# generated sequence: Way
# Wey sitsed a marsey nowalch who slwors like threeinch?
#
# "The mines the mrorn
# You Le hn, yaare see
#
# iter:10699/30000 loss:1.8149341344833374
# generated sequence: Wood a me cook in m shoathoned
# The vills so mrot
# I'm sir hlorge on noch to hrows bit to
# Bewways think
#
# iter:10799/30000 loss:1.8110133409500122
# generated sequence: WHone, B't I sill leturn ingotty
# And it ard hard it say hily
# Oxomelitesh, and I here dround! i't you
#
# iter:10899/30000 loss:1.8289844989776611
# generated sequence: Whyre con't sede
# A look afery
# Bould you Like you stabe dilid up-no bud, it seed
# Won't rus, bach forga
#
# iter:10999/30000 loss:1.8353816270828247
# generated sequence: Weld  forsev?, sra, you that somerelame on looker!
# Right
# So I coucoun
# Goadis, this not the get justir
#
# iter:11099/30000 loss:1.8186653852462769
# generated sequence: Wyttore?
# lyep up muve in to me on the dius my vove
# That fighe lime the feel
# And sick at macy you're b
#
# iter:11199/30000 loss:1.804207444190979
# generated sequence: Wourd it
# I all the, onlyoder
# She dony my never to dar want no dtopry with, roor,, Goold whode dowkere
#
# iter:11299/30000 loss:1.8234426975250244
# generated sequence: Waine
# So I dunss
# She like ain't on due
# Exouse you home me me come me
# Side don't do
# You're but just ha
#
# iter:11399/30000 loss:1.777527928352356
# generated sequence: W
# But I sten mam, onTurhaad
# And me the singer of brokul we'll woo- spook
# And you how hick anore all.
#
#
# iter:11499/30000 loss:1.809513807296753
# generated sequence: W wordd no poment
# her tore droiloda
# You drourd nouel pread
#
# Roight Whises too live
# Love me, wingant n
#
# iter:11599/30000 loss:1.8496688604354858
# generated sequence: Wike wher max . when plean no's don't canbero"
# "Welchs frit is illy betep
# [Fis with a cheack
# (If I da
#
# iter:11699/30000 loss:1.8744733333587646
# generated sequence: Wish to fure magisy
# On I wkope you lack come so cattane
# Owg I neine bebs the sampep the polpanw you
#
# iter:11799/30000 loss:1.8401052951812744
# generated sequence: Well ming alone
#
# We cowive awaip, me can't be
# And is you
# And could it a
# Canse down
#
# It's kakake lime
#
#
# iter:11899/30000 loss:1.8614329099655151
# generated sequence: We my
# Frevy She's gone ey-love, From timn (to-an't stor
# The we're on you're
# Thatsh's spanning evernar
#
# iter:11999/30000 loss:1.8026032447814941
# generated sequence: Wigcace we a day is canfaze abe murly
# Callout walk shut in not can slaep extart qoir
# They's stull to
#
# iter:12099/30000 loss:1.8450405597686768
# generated sequence: Whin' and don't ling
# And highten't livessed"
# "I love as heart
# I kyalcine and we flud past some
# Bros,
#
# iter:12199/30000 loss:1.824073314666748
# generated sequence: Wh
# It's to lora in i post
# On this your allssich and the nutiricher
#
# Biggould my life dook
# Shenere in
#
# iter:12299/30000 loss:1.8041934967041016
# generated sequence: W wled"
# "See warding feel where a care.
# Good the hold neapays tance
# There be to thrar I down,
# Deads o
#
# iter:12399/30000 loss:1.8308651447296143
# generated sequence: Wit see
# Can, yive Or the won't
# Euch
# Tonight over thinked
# And will Well my and ever stone
# But look alo
#
# iter:12499/30000 loss:1.8688784837722778
# generated sequence: W they
# If mnowe, good aroundy
# "Handing me nef
# tever creem
# More, piger tist whereds
# Alm my rounds bure
#
# iter:12599/30000 loss:1.807302713394165
# generated sequence: Wh o-Wath roy alonet main good peed wasing anyone Quve
# Through see way is op on the one want nepwerid
#
# iter:12699/30000 loss:1.8194438219070435
# generated sequence: Walling is
# Light)
# Takesin' to be
# Yever love
# who sonce to hand
# You going undre's streasen on loess on
#
#
# iter:12799/30000 loss:1.8258064985275269
# generated sequence: Wivy mound
# Ad of the finces me
# We're leking
# Why give u sead End sunny
# Hamed ever Rout the beeny
# Shis
#
# iter:12899/30000 loss:1.8018262386322021
# generated sequence: Whrosing to sitper
#
#
# Aher the babior trutoN
# If I'm your likes do the beens high modes mind"
# "Get Soom
#
# iter:12999/30000 loss:1.820540428161621
# generated sequence: W
# By body it a little.
# Pre'll bemerle nighin' stop wasted quavy
# There'""WT wlmy bemorly
# In the gratch
#
# iter:13099/30000 loss:1.8419097661972046
# generated sequence: Wo smane us and wim.
#
# Some the trith it susten Now
# Come my comerybing wends't and wordo
# SoTt man mome
#
# iter:13199/30000 loss:1.7874386310577393
# generated sequence: W.'nn on an of hnun'the it Love
# come abniund of the wirl it I baby, mine another don't streen
# It'h In
#
# iter:13299/30000 loss:1.7873231172561646
# generated sequence: Wice you a lie
# And dop't nemsrast
# When who cromsor a this life reothe
# And a money me jaycil and give
#
#
# iter:13399/30000 loss:1.7866780757904053
# generated sequence: Wench with winns the listle
# When the prytow eld the martell man same
# But a the saxkove ghir're baby
# W
#
# iter:13499/30000 loss:1.76967453956604
# generated sequence: W these soul itslocge
# Baby goning oofn lost
# AFciof Me; and ap those todnig cross
# And carfimh the tedo
#
# iter:13599/30000 loss:1.8134386539459229
# generated sequence: Wes talks turn
# By neversly macing to sing
# And hnill e6ring work
# it's a ran, this I'm om that down
#
# "W
#
# iter:13699/30000 loss:1.8797364234924316
# generated sequence: Will thought, gonne lite oCelites
# Don't good other is trea man
#
# ONerod on it's for the in the wor.
#
#
#
#
# iter:13799/30000 loss:1.7750630378723145
# generated sequence: W il the flout
# And I hame burusres babling
# Ever lickenf the life
# I walker
# This what a siewiny going b
#
# iter:13899/30000 loss:1.8124403953552246
# generated sequence: W hae don't of mother my ey
# Rag aways you need you her Alen's a way, Life a sould rut of do
# But you'
#
# iter:13999/30000 loss:1.7720502614974976
# generated sequence: Wh rnoes hoperwisun't whisp two get come it's comtores to untlought"
# "you're know he can't jist Doll
#
#
# iter:14099/30000 loss:1.7772636413574219
# generated sequence: Wi'nid around this I gus her eittight
#
# "starl he worker me a tant the eyen
# Rut grary yid botuse
# Sighy
#
# iter:14199/30000 loss:1.8437116146087646
# generated sequence: Wrie'. cou'd little sound het the want, tarerly ouun
# Tear all a but wear
# When yourle make, oh
# Inout's
#
# iter:14299/30000 loss:1.8643145561218262
# generated sequence: Waigis cotoson I worlder up
# And on I just eed I dead
# And I cordernwer,, I pum me
# And it's stopes of t
#
# iter:14399/30000 loss:1.7669298648834229
# generated sequence: Wte You're waith
# Sail doc the pay a molungher fains
# Wongunsorse to make I'd chaed
# I not the poweting
#
# iter:14499/30000 loss:1.77974534034729
# generated sequence: Whoud all his stor cookul coll
# Oh, Cay
# I fatte that I bee the cooking mysar a pooin her ever there
# Le
#
# iter:14599/30000 loss:1.818784475326538
# generated sequence: Wla get reer ye heroursa to faint
# Arelicep all yead
# I live you fasd'o
# Tiigh the womis and ray
# Oh!
# The
#
# iter:14699/30000 loss:1.7623018026351929
# generated sequence: Wer drock away
# at.
# Wlow's hapsinell kight
# And it, was you was your hix a cruoth rist sweet tiel
# Need
#
# iter:14799/30000 loss:1.7701443433761597
# generated sequence: W whe the dop me way son
# So see So dig said the way well can dockis no do on, work, pootiil
# me's wind
#
# iter:14899/30000 loss:1.8315852880477905
# generated sequence: Ws a lix
# We're ever bee Guts
# That a sing a takeg with he'd?
# So it holding indace
# It's Jume to of peat
#
# iter:14999/30000 loss:1.8137904405593872
# generated sequence: Womebide be no The're alite-told
# Cause then unyfed too freed want
# Totn saids werrol cade instand?.
# Un
#
# iter:15099/30000 loss:1.771971583366394
# generated sequence: W I mafa, I mool
# So you calkept to ever whem eyesacce
# Wheed us my thalther drocker Parkor the porpay
#
#
# iter:15199/30000 loss:1.760453701019287
# generated sequence: Wile malticn down
# The the pain of now you bee even's ending to cold
#
# Come mayny somes ar a play
# Nea
#
# iter:15299/30000 loss:1.8195738792419434
# generated sequence: W you tarn me
# We can't a sarady pace me
# 'Crow has and a the pollity
# Got a nick to me a lofe want
# Inca
#
# iter:15399/30000 loss:1.7710527181625366
# generated sequence: Wert But liceeated you deinges
# loilet
# She coiln bes abe um
# if the in the ploed ussaye, yeah
# ""*ac a C
#
# iter:15499/30000 loss:1.7608970403671265
# generated sequence: Wome my palime
# some
# oh, was I yuad alay
#
# I love it airound there,
# you jumiroll one had you
# Thate smit
#
# iter:15599/30000 loss:1.7872507572174072
# generated sequence: W ly-baby to too lonk
# Forepcut mrooad I beconedray -'re got mast, bign"
# "And you baby thas I'm bay in
#
# iter:15699/30000 loss:1.7305582761764526
# generated sequence: When you.."
# "I'm samers
# Ahing looks of that dilling
# Jocm of love as looking
# Doneod mayy the wid once
#
# iter:15799/30000 loss:1.7733609676361084
# generated sequence: When let and to pong.
# No timed there to child she lide my beense / say
# Rut sackion ret tristce
# Lert Y
#
# iter:15899/30000 loss:1.8336206674575806
# generated sequence: We with you pet dad
# Jcon go you love in I fee the drame, cinno Astide
# Seot Come thirce fud ofe. Speed
#
# iter:15999/30000 loss:1.7816263437271118
# generated sequence: W made askw) tall ale
# Olon't I life on you ar as me
# Oooh nu lonk the paice.
# Your guve wat me me not?
#
# iter:16099/30000 loss:1.7809598445892334
# generated sequence: When you're baby
# my what I bead,, and you wor'm coldurattel mes
# No'd I gere starked dries
# Whobe your
#
# iter:16199/30000 loss:1.7387491464614868
# generated sequence: Wan your around
# If -yeah good
# See i this me there's came theur not
# Hass a fings ifpy Drey difsat
# So t
#
# iter:16299/30000 loss:1.7595890760421753
# generated sequence: Where though mysing?
# Whole you're your way you beet
# bnys I don't you hand the torldly the wurs
# You th
#
# iter:16399/30000 loss:1.7717289924621582
# generated sequence: Wides cory eight fun like brother)
# Tonight if, time uf someous
# Hon I times me
# You night my and keep i
#
# iter:16499/30000 loss:1.8088740110397339
# generated sequence: W the wants I'm been
# Your ford reantin' drefelrow
# Su the are the
# Durrit a pring likany untell and, ow
#
# iter:16599/30000 loss:1.7319597005844116
# generated sequence: Werody..
#
# It ankcills with held we lack
# I have you fooray
# Plecumy that revenything of me; it all brea
#
# iter:16699/30000 loss:1.7494447231292725
# generated sequence: Way?
# I um you hoo sailed clay sull
# I the waschan can baby
# It's have how ahr That I ne will wece tell
#
#
# iter:16799/30000 loss:1.816999912261963
# generated sequence: Wainslake ham hird
# Alonan somrestoray
# I wake fart they'res my mootithines oothing
# Sleeping to didfut
#
# iter:16899/30000 loss:1.7744390964508057
# generated sequence: Winit gave I fill around anger leanty, you like you nud.
# Somer um on the fawt you
# With no ttuck insic
#
# iter:16999/30000 loss:1.7551701068878174
# generated sequence: W? .h-don't keap one elver
# Oh
# coure thisching Me you cillih
# I lone me comes
# And recnaed opel
# I've oy
#
# iter:17099/30000 loss:1.7527967691421509
# generated sequence: WMely
# World sick body Do me
# When I guid i'll luve I crie pray or you lox
# I won't well lally she's
# Shr
#
# iter:17199/30000 loss:1.7830532789230347
# generated sequence: W a hat you bell on faha
# This to padonelenol
# I knighil to me want?
# I and hand hole
# In night now I kn
#
# iter:17299/30000 loss:1.7202409505844116
# generated sequence: W hro,
# I kalled to hertre giins
# ever's sing
# Show your propun.
# Yeah!
# 'Cause and we got togn spakt, the
#
# iter:17399/30000 loss:1.7449567317962646
# generated sequence: W
# Mube upny brokagirs in the doed tell flame, hear time
# Like alway so pallizel me out
# it amm friend h
#
# iter:17499/30000 loss:1.7556626796722412
# generated sequence: Whesher to gerie
# And she Op, sic
#
# Thank up to ghance forert
# I wanning no and like atnettothd, again
# F
#
# iter:17599/30000 loss:1.7948205471038818
# generated sequence: Wil detm you
# ante a hell he all whys fasture
# The listar me
# We stenden hions too love therereely and w
#
# iter:17699/30000 loss:1.7931510210037231
# generated sequence: Wmation
# it's me a midin' around
#
# I hopen see Homn
# I from fon you this life the san
# I just a sumce
# Ase
#
# iter:17799/30000 loss:1.7651618719100952
# generated sequence: Wheraright, heT.
# I knoops I be callem
# Now wheror ot of dexher ohly
# Weering it of a reftarod so Gad my
#
# iter:17899/30000 loss:1.7819887399673462
# generated sequence: WAys Please of this your hing may
# Can't a I son sonh rid
#
# "Yeah Rever of son rly then?"
# "Mnode, have
#
# iter:17999/30000 loss:1.6815847158432007
# generated sequence: Wull me to there you can tonight me
# You herouck and blersise
# Tso can my cutfint, my baby, boty
# Jast c
#
# iter:18099/30000 loss:1.7196440696716309
# generated sequence: War of the hampimi roalss though
# Don't fall now you
# 4D Rw,in' the weroone comsize cost
# You, hith that
#
# iter:18199/30000 loss:1.7258747816085815
# generated sequence: Wes us crease it nes, no leart on
# There's no troucired with and i leaved
# Thiss one, take through
# I ma
#
# iter:18299/30000 loss:1.7362651824951172
# generated sequence: Where
#
# Wear likele to boney open to kewm time me
# Lebsing tocer eyes no be
# A the rlake tire antto
# Pley
#
# iter:18399/30000 loss:1.781685709953308
# generated sequence: Whry, it that lichat]
# My loxgs up a, yesiund in do (Where dow
# j|3
# Chon I stand, ohe).
# Gif of my got t
#
# iter:18499/30000 loss:1.713789463043213
# generated sequence: Whated nothing is pistad
# The love, downer-tonos
# Light ttore forold aways alone aloog
# You a with shot
#
# iter:18599/30000 loss:1.7440228462219238
# generated sequence: W farces thing wolls touke wi'de
# The sart night willnds to caun times
# Every this seces
# Seet srail you
#
# iter:18699/30000 loss:1.754040241241455
# generated sequence: Wer we're is lever
# And sive does be oe, Rogcentee
# An no bef of a groper were free, Oh ewelss some
# Mo
#
# iter:18799/30000 loss:1.7635712623596191
# generated sequence: Wn we won't sluts thear
# With the sick no'r troeng
# to smot the Stay hopalem bety Say
# you it how,  I dr
#
# iter:18899/30000 loss:1.7847410440444946
# generated sequence: W I loed to dead a usating orle
# Come
# But you'll ooh not exestina.
# Tone alight rocking
#
# I knoom a roll
#
# iter:18999/30000 loss:1.7642773389816284
# generated sequence: Way!
# We're kear thim donis sinning with youdte till say
# From again you're see
#
# you won't it all did m
#
# iter:19099/30000 loss:1.7206416130065918
# generated sequence: Way,
# You feece the wind reas
# But you way as you say.
# In the loven to me truth
# I'vl man my
#
# I lovem of
#
# iter:19199/30000 loss:1.7484610080718994
# generated sequence: We whas mutive turnyt
# you bes it the hearth eyes
# Whink ried ristend
# Get is it pripingt inibring
# The f
#
# iter:19299/30000 loss:1.7984135150909424
# generated sequence: Winus or be me
# To did the eied homes to that I down
# The know yhabart fray get you your lighto forting
#
# iter:19399/30000 loss:1.7790507078170776
# generated sequence: W rabudy
# You'd but talfirn me measy
# Puth this one make anybing I be
#  what the heard stapgiofs way don
#
# iter:19499/30000 loss:1.7274895906448364
# generated sequence: Wh
# I got sucr too futted
# And wog the preap reads I!
# Your the his in the and the colcettun causm
# And
#
# iter:19599/30000 loss:1.7645759582519531
# generated sequence: Wils
# When you fiser come on where
# I sink for on round at
# Quuld it hell
# BeY it betuse it caild awetty
#
# iter:19699/30000 loss:1.7135919332504272
# generated sequence: Wells the buts i
# Don't know your ttarce"
# "Ramonp]"
# You was you stark the nister whing me, but born
# We
#
# iter:19799/30000 loss:1.7659330368041992
# generated sequence: We sayus
#
# Leaven com don't killeseling makes.
# The eyes we lungy me fixe
# The fool cread he son bady
# Yo
#
# iter:19899/30000 loss:1.7228046655654907
# generated sequence: We from reeding to keeps thome
# I'll didide your tone sold wither
# If the tonight
# The nagedting world D
#
# iter:19999/30000 loss:1.7928862571716309
# generated sequence: World.
# Do i that I canch. Bay
# Sometht..
#
# What beesy Lidted)
# Tell yay & -|------------|--------------
#
# iter:20099/30000 loss:1.7243778705596924
# generated sequence: W-I know the down ya are
# When you weet don't as almound
# I done a mife dreeped one you mamfy byliend i
#
# iter:20199/30000 loss:1.7276194095611572
# generated sequence: Wmer the she whink
# And mostering be is on you not to bak
# It'g on the grwoll.
# Fee drasthine (the laad
#
#
# iter:20299/30000 loss:1.7402757406234741
# generated sequence: Way but it-fropdn's condun
# "Ore days and I stop
# Oh There arlind are of or the words in call to to bed
#
# iter:20399/30000 loss:1.7140140533447266
# generated sequence: W)
# Walk
# I have it up whape
# oohous alone
# there eyes and coulder in steries to stay
# Ahenines antimet th
#
# iter:20499/30000 loss:1.6541680097579956
# generated sequence: WDon't sink
# It's how letting ilceen can (be to musting on mist about it)
# Ourtht is Cauntsis cand a s
#
# iter:20599/30000 loss:1.8170684576034546
# generated sequence: Won't be reiling tone sying you to come eneryming?w.
# Basy said and I'm me
# straineround..."
# "We drees
#
# iter:20699/30000 loss:1.7662625312805176
# generated sequence: Wh in the I cosiud
# You are just want
# Wheull me sche the beess hey arplal gat I gimper
#
# It say of my s
#
# iter:20799/30000 loss:1.7436176538467407
# generated sequence: Wushin' to I gied in wominot npunth bely uf are Gotna bure
# 'Cause ait dist fiddusins the strippm
#
# I w
#
# iter:20899/30000 loss:1.7262743711471558
# generated sequence: Way suarsican
# Stop hoclum the time 20 with make, i'm love to you she sTer you danging that it as go
# I
#
# iter:20999/30000 loss:1.7334667444229126
# generated sequence: W it told wore mes!
# It stops here the wooldair so be
#
# Well ever panny mister they wanna
# Take alrown
#
# iter:21099/30000 loss:1.7273845672607422
# generated sequence: W
# Ohh?..
# I'll sun the prace, back
# I goodwe dope at the steak
# Say care is you shot
# Diesagant cold ot l
#
# iter:21199/30000 loss:1.7669262886047363
# generated sequence: W , wall
# Me baby, who your hrow havs to pyed
# I'll every fame I want us that you could's too starnever
#
# iter:21299/30000 loss:1.709728479385376
# generated sequence: Ward strings dressain
# You mems no grt life yeah come togind"
# "[head to that and you'rin' mist your sh
#
# iter:21399/30000 loss:1.7370972633361816
# generated sequence: Witay
# See missep come dillin chorusely wete my another living to hang hearned
# no bream alone your swe
#
# iter:21499/30000 loss:1.7213020324707031
# generated sequence: Wrond homes do?do.
# Get to me to mmuet hisse blways two you know I dresrec)"..
# Down, you're that love
#
# iter:21599/30000 loss:1.741772174835205
# generated sequence: Way of tha friend
# if she may
# That you cast anp eye bollter too
# Thich if cears another all are
# The doo
#
# iter:21699/30000 loss:1.683545470237732
# generated sequence: Wer the saider a lord rasn neamp out
# Neagh my me
# you keep love you u
# Crudcy's other, I've go?
# but I l
#
# iter:21799/30000 loss:1.7717660665512085
# generated sequence: Wn you're true to love in
# Everyday will crispedleds been be it
# Oud take a tally burm,
# the mool and se
#
# iter:21899/30000 loss:1.7164130210876465
# generated sequence: Way't thesel lame,led
# Bot wakevers plows is mn
# I wells love on the bluvring forgetrf in is that fores
#
# iter:21999/30000 loss:1.7059931755065918
# generated sequence: W all mtanre Corediir me hurgredes aplepstic
# Here well I've sicnlie
# From makinabe times your eah
# Now
#
# iter:22099/30000 loss:1.7579413652420044
# generated sequence: Wtedern)
# You al it sig day, reaths thring mome I long dear say
# she it more you abe a deed to. found t
#
# iter:22199/30000 loss:1.70853853225708
# generated sequence: Waet just abthousle now I to deepin' and all otnought
# I cannlaar mume avdw
# Anthny's in waitive
# And I
#
# iter:22299/30000 loss:1.7228128910064697
# generated sequence: Way theyShoo mack are won't love
# Give lawpive you doe
# heryan ever pestrrang blant
# Well know when sexp
#
# iter:22399/30000 loss:1.6903440952301025
# generated sequence: Wuns of ?..
# Cau you farkinged to make to mil
# We gun us (You i hold it do betVll, oceens
# Don't be can'
#
# iter:22499/30000 loss:1.7239364385604858
# generated sequence: Wheres baby shide
# For. what well my back way cat bforn
# And long no Mnarnue betsan
# Charming of down aw
#
# iter:22599/30000 loss:1.7381511926651
# generated sequence: Wn gentul ay my life mymed
# Heartites, alone...
# He is for the living of what
#
# Have to pife)"
# "Waitids
#
# iter:22699/30000 loss:1.68570077419281
# generated sequence: Whes broouve highs all "" hot to grright, to skile bur caones akie
# Why all the hilln 'sy with the don
#
# iter:22799/30000 loss:1.6765450239181519
# generated sequence: W you
# Wholed cros it are with it babyh
# I'll have my hick
# Frown cry ugain
# Well her jum dow mowt old bi
#
# iter:22899/30000 loss:1.7359806299209595
# generated sequence: Wuy I've the hing
# Tonight at whine falds of a listj
# She'gn the garding, Javethriedirnich too
# Just wan
#
# iter:22999/30000 loss:1.7349469661712646
# generated sequence: Wettet to glincle are nexereds to little they
#
# Iattbiles
# Of That drease
# So love
#
# Oh where, i cause u
#
# iter:23099/30000 loss:1.751890778541565
# generated sequence: W
# How did munces
# A laidsteoply cattion out todies
# Somekipering winmoves unties les
# And myselw you and
#
# iter:23199/30000 loss:1.7717219591140747
# generated sequence: Wer own true from this mothe of a rogrs from you
# A dectty or when you got give gonnu the pitkine
# They
#
# iter:23299/30000 loss:1.72169029712677
# generated sequence: Was, I'm through not shos theme wortth-for the work!
# orou lovs me cot do.
#
# "One never hears a cathin
#
# iter:23399/30000 loss:1.765456199645996
# generated sequence: Wn cathing that I'm trie this to mal
# Everyy night anotikind on plaze
#
# Ghorrus, So jteals
# Break pare a
#
# iter:23499/30000 loss:1.7272720336914062
# generated sequence: Wealty"
# "Hat alond you know they work
# He's frees
# Jist and a casther get
# Dights us shout it's alk to f
#
# iter:23599/30000 loss:1.7270407676696777
# generated sequence: We strong of gronna
# and but I to cother.
# Shaiding no sprOmay
# But stop bum, I've are been a cet I wall
#
# iter:23699/30000 loss:1.7649372816085815
# generated sequence: Way
# God a has do ding now blain goin'
# 'co I shike you when the haphin't own I the moneied, live, tryi
#
# iter:23799/30000 loss:1.6928668022155762
# generated sequence: Well all with light
# I'm alwaying the panry lade up they wacge
# Listeet dtrever hat knows zelld
# It
# It's
#
# iter:23899/30000 loss:1.7092618942260742
# generated sequence: Way you can thrirge you neebing the silind and clonger
# Love is yeah, Do a of yelh
# I'mm and lovpince s
#
# iter:23999/30000 loss:1.6874210834503174
# generated sequence: Withen ib shattle.
# [Ca sat you are to goe
# Ary you go more the nis
# He gog, -bable, you don't pary
# ""Th
#
# iter:24099/30000 loss:1.7390471696853638
# generated sequence: W thet the maunse noole do
# Byin' bear
# And whet is my byhet to toich, yeab soontunat, sinur
# Who'ckienh
#
# iter:24199/30000 loss:1.654639720916748
# generated sequence: Weserss it's on down
# It loved in she
# I love the rite.
# In's we
# [Ch,
# I see you kand yourle stord
# No ble
#
# iter:24299/30000 loss:1.7503808736801147
# generated sequence: When i'm want I've clybes
#
#
# So Till ground
# Well the wasn't help in same
# Hy sich on ouw this Gar?
# I do
#
# iter:24399/30000 loss:1.6954973936080933
# generated sequence: Whate alright,, And
# I only three I the lord a long who sweet town hive of her back
# Just catcheaghathe
#
# iter:24499/30000 loss:1.7622476816177368
# generated sequence: Whele she's befos it ruse
# Hold in you're gonna seeking in
# a shoutting I shaked fived to you
# They're m
#
# iter:24599/30000 loss:1.7200154066085815
# generated sequence: What ploosath
# Eseing so frame you dentions for the man
# Gow for me the store rong of I nevey
# I turneve
#
# iter:24699/30000 loss:1.6925309896469116
# generated sequence: Wade fave
# And fadust in you frouth o rear om sleaanyy
# We adt light to goands bringes uperort all he p
#
# iter:24799/30000 loss:1.722429633140564
# generated sequence: Wake on your pleabm,
# I'm run the nights
# One'f kallen dan,
# It mucher onf,
# Could holdin' ever me
# Well
#
# iter:24899/30000 loss:1.7227277755737305
# generated sequence: Wrods from your micns
# you get up all in my more her to got of tean
# I need fallin' lost the worl?"
# "I
#
# iter:24999/30000 loss:1.6995267868041992
# generated sequence: Wnd - but crangeg down
# and I'p all all a cryfore been starts
# I't grow you enough, we arl (Sice, relie
#
# iter:25099/30000 loss:1.7388840913772583
# generated sequence: Wht will singer, never um high the rub
# Wild way to (
# A hoa-] Mayke me forel to show bread her ever
#
# iter:25199/30000 loss:1.7149617671966553
# generated sequence: Wet you aswe , can
# What's let my merly
# Dreave yemake you every
# Fecle's fripas come leen rold our that
#
# iter:25299/30000 loss:1.7108432054519653
# generated sequence: Wayo,.
#
# 'Cause when it fide I don't trayt too
# muke dreams world crawm
# Pably on corlit
# No own keep coi
#
# iter:25399/30000 loss:1.7005524635314941
# generated sequence: W
# Oh bataysores you see maning heart,
# why whole The need deart
# me around Me the cithG
# Our kaid to cha
#
# iter:25499/30000 loss:1.7266340255737305
# generated sequence: Wing stalf blarvirr
# Get to look who what a moy
# I trrive
# I will come to the every harling
# I know it s
#
# iter:25599/30000 loss:1.6819844245910645
# generated sequence: Wnrec
# Wa tiel can't now I skittle be, don't show that you drue, put I'm you down
#
# ""Nakt, So Wh ok el
#
# iter:25699/30000 loss:1.6735856533050537
# generated sequence: Wied, tear am the base
# You heard on mise mes just of find you
# And led of on-we me
# Blues a little got
#
# iter:25799/30000 loss:1.6927133798599243
# generated sequence: W in
# *ining gonna need're like and and abouts heavedly right and a disseds leam word
# He's a frow, mod
#
# iter:25899/30000 loss:1.7012888193130493
# generated sequence: W insell?"
# "And you would forewion
# I've alongod is now.
# (I never walny show you neveror love;
# if you
#
# iter:25999/30000 loss:1.8056954145431519
# generated sequence: Waeth bnow when I stim
# Don't arways rike sawt
# Pate as the one theowe we call can the if
# You can't wmi
#
# iter:26099/30000 loss:1.7374716997146606
# generated sequence: Wime a firds
# Bleaved bur
# SAy you like agains.
# Hive it with the couse down babe
# It's and blame
# I'm awa
#
# iter:26199/30000 loss:1.7197585105895996
# generated sequence: Way a bead lorge in rast truusich
# An the pat got linfs
# Int-my then a worky to you
# Rujg I've and that
#
# iter:26299/30000 loss:1.7088631391525269
# generated sequence: Wain how
# Not of that's knosevel a high
# So 'bout the night of as when I'm never the that we'd lain
# Get
#
# iter:26399/30000 loss:1.7196286916732788
# generated sequence: When tran, Coming a beacks
# Fince, how when you're hiD ho.
# Androwess and baby
# And yeah
# A wouthh seed a
#
# iter:26499/30000 loss:1.6845752000808716
# generated sequence: Wah
# This gitcicifeth it's south me  lose, whit a Rair)
#
# He sansur of the Ghus live mation
# Ruited dich
#
# iter:26599/30000 loss:1.733193278312683
# generated sequence: Wond on crives think this cands
# i keel alive. "I sat don't knind, hope watchoss"
# "At hurneveolly and
#
# iter:26699/30000 loss:1.6819645166397095
# generated sequence: Wites moly that I have the romed
# So play madars to get your time
# I so who
# I'm all sleep to sun
# Goy
# He
#
# iter:26799/30000 loss:1.7698894739151
# generated sequence: Wunsbote
# Reveryroding to litted! b't reone mind,
#
# [C-Me,
# Clowon't somes jesta Justing"
# "Monet thing a
#
# iter:26899/30000 loss:1.6886069774627686
# generated sequence: Went
# To be along do, hearn a Ilwin I Get you"
# "I will wass world Throuth you.
# even
# You been, I know
#
# iter:26999/30000 loss:1.7621924877166748
# generated sequence: Way?
# Got thought new chilly, hap to will waiting that that i wrong to somethher make all some
# My coul
#
# iter:27099/30000 loss:1.6947487592697144
# generated sequence: Wild agause the bly afce
# 	That's her a snaxes in I treate
# I'm keed
# Wondurdt in a kifsing so take
# I ko
#
# iter:27199/30000 loss:1.7317038774490356
# generated sequence: W bmiepbudy to the wait. Thing just nod help sunnt and aurnied live on)
# In this sign
# Watpyting bear
# S
#
# iter:27299/30000 loss:1.6808363199234009
# generated sequence: W&V May
# I do, I'm line, when it's don't sin' when you abeing this"
# "In me a happed overy all neaved
#
# iter:27399/30000 loss:1.6681842803955078
# generated sequence: Wnrended still toll, if do you with me
# Saudin' untelf he raun thing it it's all gost look of loney on
#
# iter:27499/30000 loss:1.6531840562820435
# generated sequence: Whet i call we'relituon I hable.
# Kiss i to night near it life
#
# The naversy him called through
# The sic
#
# iter:27599/30000 loss:1.747961401939392
# generated sequence: W would sit a ""nedtrou(dany we alone
# That's mover been your book all I say
#
# Rumarady you pone of sur
#
# iter:27699/30000 loss:1.7162820100784302
# generated sequence: We Dins liveb redothen for to kasy there
# and the silination, many rold in the, reen and thing
# You day
#
# iter:27799/30000 loss:1.716927409172058
# generated sequence: Wank way caller after drirdingur
# I to bab it's come cire
# I'm right night Cohand you
# Was'st as forewed
#
# iter:27899/30000 loss:1.7077574729919434
# generated sequence: W Oh, rosed, some it buckaon
# Start depe it fleeing
# And I drom to my that 'ell
# It's ark finn
#  the Anti
#
# iter:27999/30000 loss:1.6705639362335205
# generated sequence: W our fale it and left again
#
# A herbeuse fell dorn all kood the sharo
# Dack blusherf
# So go eye and you
#
# iter:28099/30000 loss:1.7012600898742676
# generated sequence: W on that's all I'm be.
# I know I'm stall to you
# High'es to the say,shing rong
# Say down our solith awa
#
# iter:28199/30000 loss:1.664209246635437
# generated sequence: Wanne, you youd moonman
# Gis and throug loed you renz
# Why you move back tried your way
# All my haypt in
#
# iter:28299/30000 loss:1.738685131072998
# generated sequence: W Wh Mind oh oh
# No, it would the luve
# Now a mind zaitpich stold we love
# ""Siil fick here you alwaybe
#
# iter:28399/30000 loss:1.738162636756897
# generated sequence: Womd
# Our devandon shinies, I song and you do your Damo
# Can'rine"
# "Befores, come fit gater to knowped
#
#
# iter:28499/30000 loss:1.75950026512146
# generated sequence: Wazlion,
# [Chroot uppay dripe
# A can dear a mean
# Ah it's on lifing that could eut be
# Migg go or a dey,
#
#
# iter:28599/30000 loss:1.7135201692581177
# generated sequence: Wn u talk here it
# It's doll by it shit if the
# Gongay
# take out out to know
# If kister show
#
# Firted cou
#
# iter:28699/30000 loss:1.683678150177002
# generated sequence: Washercanner
# Heles, I steleth
# Ever's hisghen to shine bad the man
#
# When I know you feel through home
#
# iter:28799/30000 loss:1.7250525951385498
# generated sequence: When I'm seeat nightal toldag to
# O
# was aboug her
# And tell me testion
# I was lake meade arody again
# Tho
#
# iter:28899/30000 loss:1.6937364339828491
# generated sequence: Wito on leen it broken goound
# But jusgs mell. I'm love the oper
# All the from the rubler left rewnt in
#
# iter:28999/30000 loss:1.7110724449157715
# generated sequence: Where Just to me
#
# SVay livire (p-sivin'
# Mach the longs hadsled thing on the worlmooon aan
# Life mered
#
# iter:29099/30000 loss:1.6996787786483765
# generated sequence: Whts
# let me on, I'm belhslinesinga.
# When sums as filling too diss the niving not man
# Cast and a mind
#
# iter:29199/30000 loss:1.7190619707107544
# generated sequence: W may going and a fanding the ansby care insex
# look pirty ?
# seem sloor os prop proagl to bewiy-and I
#
# iter:29299/30000 loss:1.652051329612732
# generated sequence: Wosed will was pray
# Now, you the keep oue arought
# I this a friess
# A with me will leals
#
# agains light
#
# iter:29399/30000 loss:1.6971198320388794
# generated sequence: Wurlioed with crar.
# Comsoe I can be down because Hill of who)
# Oh, I were go I spop you could tryir to
#
# iter:29499/30000 loss:1.7016226053237915
# generated sequence: W,er one lifeows a home healling a'm you stul
# I know the and my pee
# Every dij nowhere xlazin' you-wim
#
# iter:29599/30000 loss:1.7274614572525024
# generated sequence: Wn I to feel
# Hold bekop Hardming ?'bior lost away
# I thunker more you can gonk for me my say
# It want t
#
# iter:29699/30000 loss:1.6847724914550781
# generated sequence: Whar you're drease
# 'wuf this fint of a rex
# Where hi most your hoass and shine rire roup
# Mucine
# to kno
#
# iter:29799/30000 loss:1.7244651317596436
# generated sequence: Welllled by true
# I can't world
# I guive mise
# As me make is we't all be strace
# I have it's shoke that.
#
#
# iter:29899/30000 loss:1.688380241394043
# generated sequence: Way
# I better, befter's when,
# WI're will is you onceshe
# Your lost mothere."
# "I want that I, the night
#
# iter:29999/30000 loss:1.6827480792999268
# generated sequence: When itel the pare
# I can't guine my hift
# It's chancentret want not the bosn
# Sopuloy
# But souse the wor

# %% [markdown]
# #### Training Loss Curve

# %%
items = [ele.item() for ele in all_losses] 
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(items)
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wn she's sfranse tear
# chausle to crame awain
#
# And I'll know I'm a goneing ain't a Are to how
# In I'm be the realay meansing me in ships
# In the wall uple comes tum make
# there to cove amore as out of feel turncends
# lights are arounds makea
# Yeah, the sweet so it one asking life that moress
# My could a man, darly gaood
# 's light been tines
# (Gesoa
#
# Got just nor, Lond with alr)....
# o, ar Has time
# Ride, crood I wild hang ) Do it,s"
# And loving there's out outigat all if you say saw
# Sidper to save again
# Ahond that we take your aiots
#
# Saj, and so latiin me with this it throd
#
# Sowlusbised all baby
# (and only
