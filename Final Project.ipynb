# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./trainlyrics.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 106526624
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of rock lyrics.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.rnn = nn.RNNCell(self.input_size, self.hidden_size)
        self.linear = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.rnn(input, hidden)
        output = self.linear(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (rnn): RNNCell(100, 100)
#   (linear): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
# NOTE: You may reduce the number of training iterations if the training takes long.
iters       = 20000  # Number of training iterations.
print_iters = 1000    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/20000 loss:3.185425043106079
# generated sequence: Wgres rres
# of dhLerrtu
# ku
# T.or
# ui" "Ha
# raw sparr woe aeruo
# lhcdaute  e
# " et
# r'
# ,on  ucoapoeuwwho tot
#
# iter:199/20000 loss:2.7865428924560547
# generated sequence: W%w gafn lyaw dot tterdpe gou ina you. shererreo heondll
# ty fheeatping fofd twent inl nt lrysu ihat d
#
# iter:299/20000 loss:2.6102840900421143
# generated sequence: Wrlithon5ongn cowt hiny wiYbly.arouutelelmether morwan iousy mladhd yow?nz touauby piacstearheldoreyo
#
# iter:399/20000 loss:2.4468672275543213
# generated sequence: Wan-
# I can thar.,
# .ef doak you youe d cll wercat
# Nou cor doue pousthon' rang tave stou whavid illnam
#
# iter:499/20000 loss:2.3730363845825195
# generated sequence: Whe wade
# A s y an mu cand sant o by,
#
# And hottr cerh ling ban wffca n ghase wasimy't doasthe Indes
#
# I
#
# iter:599/20000 loss:2.346517324447632
# generated sequence: Weduc!
# Fellf fhek the be ke wist
# You mef: thiug one ileging
# "a lout sel Everes InEill batk hit te sel
#
# iter:699/20000 loss:2.342468500137329
# generated sequence: Winn 1n allond on sle to on yowa hs pallatidEeid soved sezatld an unk
# Gone tustl on thlo-govine iott
#
# iter:799/20000 loss:2.2790887355804443
# generated sequence: Wimings
# Thengsingongitainigst-an's somessoeg hoost, sutptolistameas is seerth
# in to go jo-kd
# se atoon
#
# iter:899/20000 loss:2.228137254714966
# generated sequence: Whanis ay epord ave awI go cerowe's doree poor
# BreyTugh
# Orire fampr's thery bexcpikeall
# And well some
#
# iter:999/20000 loss:2.140886068344116
# generated sequence: We kethee theneSs meckmy gonis wownint
# WhChe id Shind you belway diveckerestacling fletorix a
# You hat
#
# iter:1099/20000 loss:2.1292004585266113
# generated sequence: Willys
# Y'm jussed noyoll tlire
# Whemats you jond, jut tue ow ave cou4 then in the clease wall thin'pre
#
# iter:1199/20000 loss:2.183896541595459
# generated sequence: Whyid hireld nable lellet mile It if your awling, bage Is it't rone old wayly unlondesstoLong bind
# Sh
#
# iter:1299/20000 loss:2.1227312088012695
# generated sequence: Witust lakeith
# I way
# dron)
# Bup kn7ths
# Have ep
# Weace be doothe fore was?.
# When (Bus ilf gut racin than
#
# iter:1399/20000 loss:2.134352445602417
# generated sequence: When the hime
# pnatsye aroussinn wertedien meevar].
# S]wartis my and ayy
#
# Thays
# Ald the vornedar
# aey me
#
# iter:1499/20000 loss:2.1022562980651855
# generated sequence: Whes now lover lount
# But
# Sreand Meke go, a aroo
#
# Whor
# And'w I baco fend I lover a sslignd now the -n
#
# iter:1599/20000 loss:2.1166229248046875
# generated sequence: We it rive atay phe ut, you the lonn
# O nall
# Dattermy so bady soll ceret dorn.Ay
# Lon the and sant ap t
#
# iter:1699/20000 loss:2.044496774673462
# generated sequence: We drety lughing ondo gom nely the fienthes a worlten over tiden I cere the weys isan bla thish heart
#
# iter:1799/20000 loss:2.139446973800659
# generated sequence: We see chell bistald get ine you prought
# And I kne so sours in tlay how
# In Ioalohtads.
# ELey?
# Ot ther
#
# iter:1899/20000 loss:2.0890676975250244
# generated sequence: We a goo ha fand a drosed
# I waknd in forling
# Bl went comgr ofe
# Banching to y
# Ry pook your keace
# in' o
#
# iter:1999/20000 loss:2.0332388877868652
# generated sequence: Whing row's just man
# Fig It atroun't woupluch
# of want und Blie
# Wher aurers
# Ohint
# And I han song, wive
#
# iter:2099/20000 loss:2.025447368621826
# generated sequence: Wh ou gon, marisp wnit
# Go dray"
# ind micinns, n ond ghou hent
#
# tounn whan you bloouedniond onay hcone
#
# iter:2199/20000 loss:2.0237045288085938
# generated sequence: We to thome baineer fall in the to fowed in that I've gatta sinls
# Wett in On read
# Is could
# Kuttire th
#
# iter:2299/20000 loss:2.103388547897339
# generated sequence: We shids
# Shink
# Then y
# ontreat youd tan, of to shit'?e duer the ay)s
# Like in the on said,
# I inllevir h
#
# iter:2399/20000 loss:2.0772557258605957
# generated sequence: Whon- your madfen
# Balk etse you wop wor
# wout you known
# All thend-."Ever
# Dile rack
# Ronay sarel in ath
#
# iter:2499/20000 loss:2.093134641647339
# generated sequence: We pone seef of trenne
#
# Rou'd this will remore to my sce
# I'L now the ond
# Plear Stadey remes
# But lofe
#
# iter:2599/20000 loss:2.048649311065674
# generated sequence: Whin' -e cored an ano the down the sle the Nast with the snetwing hprey you'r core my make ext ive's
#
# iter:2699/20000 loss:1.9906058311462402
# generated sequence: We 'ver the sordoon thes in usay, ous tareedr it?
# Sel
# Crcalling
# Tulliky
# Thele
# Fored get
# Tof likes af
#
# iter:2799/20000 loss:2.1066365242004395
# generated sequence: Way hert're know I'm was blantelin Din's nowis  a slantar is ssees Lolk that fove
# ald ghes But  anget
#
# iter:2899/20000 loss:2.0213117599487305
# generated sequence: We can't lagm
# Rut fays hight
# No, prith
# Drys for chirus
# Reery'rand are 2"
# """I what
# Hay
# Ehhor lood
# Cra
#
# iter:2999/20000 loss:2.0010576248168945
# generated sequence: What I we dalinss hexring I soait wroldoki sedam
# Thiros)
# Caviry boend right you say me"
# "Whit yor me
#
# iter:3099/20000 loss:2.0058035850524902
# generated sequence: We time ant the attit sugnting ofterode..s
# e", esthin', candy that thake off
# Un i knook timel, to don
#
# iter:3199/20000 loss:2.0278847217559814
# generated sequence: We cone to get in are chas stilat moke bohtay the sooobie on foh you thark a to
# ThaC sive knock a cro
#
# iter:3299/20000 loss:2.03574800491333
# generated sequence: Wey
# Deice
#
# (Ol eblinglestlond we heart lofe
# |ta,
# So yreplist fxought alomt,, lee shoued allwin
# To be
#
# iter:3399/20000 loss:2.004672050476074
# generated sequence: Wees on in my bruy
# Avill morll it stownh
# Tr youedys
# be oneshame, was to the grong and the
#
# Somes ow y
#
# iter:3499/20000 loss:1.978273630142212
# generated sequence: We rean do in the that wformed her lased do Br(m ste sich the line your know yre from thriel oftones
#
# iter:3599/20000 loss:1.9881343841552734
# generated sequence: We night nere on my the gle
# I so cr,
# It I caverie kmach, bot you cot me hor The slinh, my hage is doi
#
# iter:3699/20000 loss:1.9333300590515137
# generated sequence: Wick one I love I says we lowd theres
# miviniwh looken shave it's sice, to crauss
# Urdant a say the car
#
# iter:3799/20000 loss:1.944037914276123
# generated sequence: Wer that the has les maxce.thing make dizn me
# And hand
# Andthed anlide
# Thing in the prstel, of corld s
#
# iter:3899/20000 loss:1.9196314811706543
# generated sequence: With in that with you yout puck that mank I like tring a
# Fougl
# Thooke pooll now
# I
# All,, shill, I know
#
# iter:3999/20000 loss:1.949154257774353
# generated sequence: Where we alw on the didntive
# You kne goout a bld oke mure me
# And and acall, I fast he you whan
# I got
#
# iter:4099/20000 loss:1.9408011436462402
# generated sequence: When
#  torys of all ceal!, grows ain't love is
# A firsaybefones out any I If my got a overy theyAn
# Buty
#
# iter:4199/20000 loss:2.0044288635253906
# generated sequence: We drack, a sllove bed it's wonsee's mave it  force to that I'll shades wan'
# Waitaing the 's a smoplr
#
# iter:4299/20000 loss:1.9499627351760864
# generated sequence: Whe's ofister fure it all
# Wes
# Not
# It's no me fains
# Heavinger cotsers dight aid
# Watkess old
# A telust
#
# iter:4399/20000 loss:1.95466947555542
# generated sequence: Well for they wilecay, I beer, the
#
# Hade
#
# Rolken is a plack?
# What dony reacs,
# All ith be col be ay m
#
# iter:4499/20000 loss:1.9433960914611816
# generated sequence: When you
# I patie aloan
#
# Whoueavy backed stce lettes olesseed, tey, beeris
# MoCklow
# Link his long you,
#
# iter:4599/20000 loss:1.9182037115097046
# generated sequence: Who give love as ohe
# Just and baby?
# I'm onou bancer
# You wank
# Our a dop know long and I'm plast besonc
#
# iter:4699/20000 loss:1.9454494714736938
# generated sequence: Wounindss
#
# It our strowhercss
# Gi something downd)
# I me..
#
# Lof the somd.
# And, you glive my
# That go
# Clo
#
# iter:4799/20000 loss:1.9218642711639404
# generated sequence: We dalget bet're guad, you forge
# , we down dneas above lick baby, I torcon Take gooz blidd
# Though lit
#
# iter:4899/20000 loss:1.9921425580978394
# generated sequence: Walk the only ist thouts ec's tixns bast og Llooli'ff yeah, fire'se it IS up whend
# Ovet foom to think
#
# iter:4999/20000 loss:1.9317313432693481
# generated sequence: Where, the words, through my ond they gonna a,, fricistio
# Shly sing bady
# Oh, bases
# Shoune hipl, spol
#
# iter:5099/20000 loss:1.9679588079452515
# generated sequence: Whee fire
# Way
# in eap your Coider thay my are whate me
# The might en
# Bllaws
# It ut flays sie bectever di
#
# iter:5199/20000 loss:1.975564956665039
# generated sequence: Where to know, You
# I've bavinicing
# Ontedd------------------------2-----------|-----------------------
#
# iter:5299/20000 loss:1.9327763319015503
# generated sequence: Whrused folmestitt kighose dirndrid act a theer you can live a brouth got of you areanging of sought
#
#
# iter:5399/20000 loss:1.9778997898101807
# generated sequence: Were't that I oplyward mees
# So my wila never man the chink mysbol ley doney your for and I'm dright h
#
# iter:5499/20000 loss:1.9423131942749023
# generated sequence: Wher ronna aray
# any to shat sore you're afoless
# And torol the spaving tho warnet abyju'd trimtistimlt
#
# iter:5599/20000 loss:1.9276319742202759
# generated sequence: When gghed of tho faken, it
# MpOh,
# He's foll, babe a newind hall thy way on conga time wightay doors a
#
# iter:5699/20000 loss:1.9663022756576538
# generated sequence: Wh_e he is like all vors drate hem gond treeattires)
# Sun baton a cautic the with I said,
# Take is way
#
# iter:5799/20000 loss:1.8544145822525024
# generated sequence: Whotte in'f you hain, aver more in stele
# a woo cabould to stulve
# tolveans
# I
# Kee id thise forgesseryin
#
# iter:5899/20000 loss:1.8589409589767456
# generated sequence: We giff
# cou't ye here
# Now it to down tour king meavy offrey o donnyous ruve what nevery
#
# I hapge
#
# Get
#
# iter:5999/20000 loss:1.8989475965499878
# generated sequence: Whon thes ne pack
# Tho roupp, just rea puine tiol stree
# No pack uhight thir your faren of, the tapcin'
#
# iter:6099/20000 loss:1.8891222476959229
# generated sequence: Whis to kiull
# On the crightl cumeay owe
# I gornow back a done spall so me
# Evetcald love you comenind
#
#
# iter:6199/20000 loss:2.0231001377105713
# generated sequence: Whrest to in wore so elp of the lack is, I
# Nown as, liff was me
# What das platting
# And what' moruve ap
#
# iter:6299/20000 loss:1.8881231546401978
# generated sequence: Who"""
# Lown on your bended friend willing rob-er
#
# Lived
# But
# It a righarin' reast reep to for So heavi
#
# iter:6399/20000 loss:1.8468995094299316
# generated sequence: Whon't knim
# Anderecepheaceen
# Fade
# I lovine
# Weee a beckest it got betime
# Leave it rice
# Millie
#
# With
#
# L
#
# iter:6499/20000 loss:1.8957483768463135
# generated sequence: We grinsing ip I'll shown sing thi know we will mOsh your the busy we the wastoff my back speatlong
# B
#
# iter:6599/20000 loss:1.894482970237732
# generated sequence: Well mavinsmene to I know re"
# "I've your earn our in ton
# And stay
# I'm gold op you have a awonat ta kn
#
# iter:6699/20000 loss:1.895645260810852
# generated sequence: What you dryon my lions
# Oh, I'll Alk any seaty tiges what I woo was
# Browin' uss come is some it's oft
#
# iter:6799/20000 loss:1.9186670780181885
# generated sequence: We find to she'm life thet es something seater to the ever the fillemo up ou denroon my do st'll hem
#
# iter:6899/20000 loss:1.9576023817062378
# generated sequence: Whyo-, live me feceres your mun in' pelople goh he, I gahe
# Judr why how -warce off from but in len n
#
# iter:6999/20000 loss:1.889538049697876
# generated sequence: Welparak draic
# So know wite eust gures you to carning byear Med's a ua, unt the wesame't a cun mostei
#
# iter:7099/20000 loss:1.9139434099197388
# generated sequence: Whon you're just you knom binion is all my ho date uavpratter cotin' over run and make
# It woo night
# F
#
# iter:7199/20000 loss:1.8310819864273071
# generated sequence: Whet lig the't gonna to light"
# "That befting that don't gonna be to fall the with uhe about from be f
#
# iter:7299/20000 loss:1.9037957191467285
# generated sequence: Wher streaning hopryethrecry
# We prough
# Jituin borkne fair
# Sthighthinkelk dorise tore strolichedreesus
#
# iter:7399/20000 loss:1.980401873588562
# generated sequence: We you pways
# (of the love and not chuthrought way
#
# Plem mt"
# "N'be ancin you bovidy of the endtiled ai
#
# iter:7499/20000 loss:1.9198033809661865
# generated sequence: Whone awaill someboly my, your lay
# Have no bratty, bleatbody, dhe slop like goten all be in to that d
#
# iter:7599/20000 loss:1.8993271589279175
# generated sequence: Whes
# "I eans away
# So a ffeak aply our hrow it a mornot, foll all my be and you
# Bebont
# your you
# you th
#
# iter:7699/20000 loss:1.9148952960968018
# generated sequence: W.
# Cealle little
# Love me, propserelatain' love, hof thay fuct
#
# That pirring you wiuntin'
# 'mous lift t
#
# iter:7799/20000 loss:1.8853214979171753
# generated sequence: Whell vold hone
# You unde
#
# That's down, I cout the beckar
# And nox your drrean....
# Helveen nefer sty a
#
# iter:7899/20000 loss:1.949361801147461
# generated sequence: W op ing restsestarlin tain
# ofly
# pust bee hep got she pmine
# I aponls, the weels lookin to said to ril
#
# iter:7999/20000 loss:1.904062032699585
# generated sequence: Wind In a grole wonf maye
#
# Shat flayoad
#
# "You don't reaty for you lasts
# Rhat you
# Than the lly noabe f
#
# iter:8099/20000 loss:1.9481364488601685
# generated sequence: We
# Lyel to
# Non sowell oft
# Tolked don't his
# I keersied alyed aby to aline in how back come to seeal
#
# iter:8199/20000 loss:1.8054014444351196
# generated sequence: Who stakess than the fool
# And sway
# siget sooding when Might
# do wanna thingme
# Unce you about 'Cound! y
#
# iter:8299/20000 loss:1.9790093898773193
# generated sequence: Whea refe us
# To leave tadning
# the good the tust ma be you thi gittey
# Lord take me ig here
# Whear start
#
# iter:8399/20000 loss:1.9193793535232544
# generated sequence: Whine to me sispler depawat all the thro than your longthe
# Wereo
# Frick need upectrow, I cofe and what
#
# iter:8499/20000 loss:1.8947690725326538
# generated sequence: We7 homethire never is endee sceper of of an le buthing for you that bit 7are)
# Dor
# Heax incalerate
# Ca
#
# iter:8599/20000 loss:1.9473798274993896
# generated sequence: What
# Lake a mays
# Fiscing somely spell abmibl
# Hes greatan con't spopp stay n thmee's us an (more insit
#
# iter:8699/20000 loss:1.9872480630874634
# generated sequence: Where my wive you
# see's ho mes gryed, ind what I gornu cyor, my, Read and whlpean to Bandered
# Paclle
#
# iter:8799/20000 loss:1.9047237634658813
# generated sequence: Why sey hise an good it be Gofmoerts an eapy,
# Game, want tane
# Dho one I hake forday I've knaw doneste
#
# iter:8899/20000 loss:1.9169025421142578
# generated sequence: Wha pleadeds, wommed you leaves, at doar
# Camibes night, ont le bly syeve Right Get a syme, I walking
#
# iter:8999/20000 loss:1.8700904846191406
# generated sequence: Who das life
#
# When light, tow and is around
# And brifll ever busuesed chatet thet kim it reeline you i
#
# iter:9099/20000 loss:1.848437786102295
# generated sequence: When I cumen you'll gathe herewly, Lent fredor man? lram
#
# hought neving slyboght you whoire
# Oh
# Them t
#
# iter:9199/20000 loss:1.88594651222229
# generated sequence: With hi'd breai t.aclinton your bet me
# And No me baft touch, a king belpen of can fun i man be weere
#
# iter:9299/20000 loss:1.8975214958190918
# generated sequence: Welled thrimitame
#
# He padea man laughtspica gettreal
# ""
# "That was a kworpy now the pouse haly there a
#
# iter:9399/20000 loss:1.8088172674179077
# generated sequence: Wathulledsher
# Better abong, is and
# Coutalllentey, humes, basyed to know, it ounsy,, we come, you'se i
#
# iter:9499/20000 loss:1.8383606672286987
# generated sequence: Whearing frrent ma tore leart gethin
# I'd world on you never me the, this?
# To trame
# Ple
# I beens, Too l
#
# iter:9599/20000 loss:1.842596411705017
# generated sequence: Wheruns
# Shakin
# Ciecrt you sad at seat you
# If il do then rown? you're do
# so
# Say the wrang to the slos
#
# iter:9699/20000 loss:1.8711267709732056
# generated sequence: We wantion, he roid
# Till don' cald my daddees
# Your yea ow curnainif it....
# Gownothing din
# Han whine t
#
# iter:9799/20000 loss:1.8466655015945435
# generated sequence: With 'carain's rold my hearm the hasce tores is from see me
# The some
# I'm eas sin
#
# I'm love be should
#
# iter:9899/20000 loss:1.829355239868164
# generated sequence: What my toped take and brop pi^s
#
# I'm foothang.
# If the waddinghing thate
# You lies bleadide
# Therow (Ju
#
# iter:9999/20000 loss:1.873757243156433
# generated sequence: Where do any knimsing, got like a through fan
# I wan chan love ax somes mind om, anays my."
# "They loug
#
# iter:10099/20000 loss:1.8636027574539185
# generated sequence: Where to to reap
# Yeurre
# Aen unfing, pends shentrdsed otroth, livflo
# You knobe
# I year..
#
# I Deeps up
# D
#
# iter:10199/20000 loss:1.8911874294281006
# generated sequence: Ward hold
# Were now to you uulh lever undeneand enluss's comps and well my bluck.'t singelluct got all
#
# iter:10299/20000 loss:1.920448899269104
# generated sequence: Wher nacting there Dreah
# Oublits whill ruts me for tur I ry rlaith the ever
#
# I lone you good of The w
#
# iter:10399/20000 loss:1.8800073862075806
# generated sequence: With unten
# Your ficks see
# Oh, it you parding
# My basky she way
# a give mustoleves gons on like no byen
#
# iter:10499/20000 loss:1.8342701196670532
# generated sequence: We I tunt the fho be is cousin' loves that aer in the iml comin' my moy
# Wey your lanive
# I cant stake
#
#
# iter:10599/20000 loss:1.8700017929077148
# generated sequence: Where mad
# We uttiow I want of would love I did
# We Spell mond
# Aight had makever me in herd like"
# "Town
#
# iter:10699/20000 loss:2.0451128482818604
# generated sequence: When whah you hid)
# He ald it sanmbet sein
# I'm gut get
# is ong, and fured wa
# I stays gonna loft tim on
#
# iter:10799/20000 loss:1.8568140268325806
# generated sequence: Where scines
# I call hergs whis the my clvight head the freink it all and tark, do what he turd
# you fi
#
# iter:10899/20000 loss:1.8786901235580444
# generated sequence: With out anyyouto cealy let my pusetio away......|--------------|------------------------------------
#
# iter:10999/20000 loss:1.8831357955932617
# generated sequence: Wher ompersirethey a ary
# Buthia istruats
# DearinAthere this oghom
#
# ighno
#
#  out you on youtroingetius o
#
# iter:11099/20000 loss:2.319206953048706
# generated sequence: Whyno me
#
# I woung this me
# Lig
# The takd
# Nad the ound on lyah thit il
# And i men mattouve, thes canny w
#
# iter:11199/20000 loss:2.146486520767212
# generated sequence: When a pound lover uguathey bo faincw
# Im no bo dolking the kidever to morting all yos anning onl agat
#
# iter:11299/20000 loss:2.0548110008239746
# generated sequence: Whild you I'd 1rent
# Litthe to youlh
# We lever mever ryaver
# I've traye on time coubhi  ky slaway
# I can
#
# iter:11399/20000 loss:2.012746810913086
# generated sequence: We wan' the gotat you me pirg ow
# I'm know Jay
# Tell that anyme on bethings dong
# Phon my
# Lill on more
# o
#
# iter:11499/20000 loss:1.975376844406128
# generated sequence: Why's sumeon't do thing the neam over cin from make staugh you doy ooky all of your tulay
# They stick
#
# iter:11599/20000 loss:1.9756158590316772
# generated sequence: Wathe's tho grer rass I canvike bere
# If Igliga, bight
# And
# Come helf never buld the name
# My right your
#
# iter:11699/20000 loss:2.0194413661956787
# generated sequence: Wire aur your you the waise I roul
# We like Bave
# Whine to stan
# Wiit
# Wher cabld sdin's her to
# You do
# Wi
#
# iter:11799/20000 loss:2.085836172103882
# generated sequence: WTinge roule I lyeere
# Boblow I is int
# It my loneyt, Back wel re wnot the rock
# Wh
# Chur so la, with I t
#
# iter:11899/20000 loss:1.9740583896636963
# generated sequence: We wighoor arvevending with it was this thes a lowf
# Drup.
# Wuliing.
# Twis te boun
# Hee we huld be a star
#
# iter:11999/20000 loss:1.960326075553894
# generated sequence: Worr
# alory stakes shoull hars all taunise
# Oh mout
# And swouldple little belis hand here
# Hell, time yo
#
# iter:12099/20000 loss:1.8802934885025024
# generated sequence: Who kneas geedac rond you shiwy come rut your dayserund
# have a lick a tark
# Hes a lood
# Sfist my prow
# (
#
# iter:12199/20000 loss:1.8735206127166748
# generated sequence: Whit vix
# Love, pro9
# Bet love But J0sty nee.
# A calecaus of wly I whined
# I night to sased sore or not w
#
# iter:12299/20000 loss:1.8621777296066284
# generated sequence: Wholin' slrack with the day, baby ever there's fremt
# Love, a'ld a like a ring frown
# All thinkll makin
#
# iter:12399/20000 loss:1.8910481929779053
# generated sequence: When mose to long, inleh
# Onder gects sun askea your ines girrer, becotire Jurn me on and me in an I g
#
# iter:12499/20000 loss:1.9702012538909912
# generated sequence: Wes gpay
# I beshers
# Athe rools I way, I thing the seres and a way
# Evinged
# anotes aswaray, you gonna th
#
# iter:12599/20000 loss:1.8926125764846802
# generated sequence: When beals
# somes
# The huck when you knew
# And wored now we coars]
# [Keakeap A pail founf Jose's round
# Th
#
# iter:12699/20000 loss:1.9221818447113037
# generated sequence: We can'?
# Rever."
# "I for I gone you roo
# I where in thip want at a shepemetane
# Ah-ulw
# Yeah, thing you
#
# iter:12799/20000 loss:1.87939453125
# generated sequence: Wald futen sting (nettlicr
# Aboud a laad
# Come let heppringh hid saxpin' torrin awound
# They's get on al
#
# iter:12899/20000 loss:1.9514820575714111
# generated sequence: Were me it, Hearts more me me
# You
# Antinestacey constic
#
# You t-y, the trout
# movernouthy, when will you
#
# iter:12999/20000 loss:1.8599218130111694
# generated sequence: Withing lood thry to can't cowston't shoppen
# Whear bymmers
# You do is the rigin' nothoull my, they cau
#
# iter:13099/20000 loss:1.8357186317443848
# generated sequence: When golling some lovlo
#
# Bom cla,bed nots
# Yeah find when me jeed be roming so nothing in thesm go ta
#
# iter:13199/20000 loss:1.7885448932647705
# generated sequence: We looh, readyner
# Helled harn the Now weast is get hem throl in your whys is gether wetcly hanumn' to
#
# iter:13299/20000 loss:1.8737952709197998
# generated sequence: With shave youp in the misstin't wint tank n your seas wettes
# Lay you thinf thingind the fer I pick
# (
#
# iter:13399/20000 loss:1.946519136428833
# generated sequence: We can to new
# Hele to stardies of exear,
# Me prain
# Load's wont thin do
# I long but do torn doion
# See y
#
# iter:13499/20000 loss:1.8372176885604858
# generated sequence: Whot it a sungew if eres ta da you
# day
# We want a'd huy ever won
# to so year timin' head Gon't she want
#
# iter:13599/20000 loss:1.8646116256713867
# generated sequence: We keelilat they can
# Throck out on ow at not tele doon to lyes to sceen out it I ren slow bustoughist
#
# iter:13699/20000 loss:1.8403418064117432
# generated sequence: With, worly
# Cat you just made hind
# On well, we you them shows
# And up and red alove next you.
# And beli
#
# iter:13799/20000 loss:1.861615538597107
# generated sequence: What heah
# (Blmske my high
# Me
# Your cold
# (gut feed--hay
# Donnoth sang barning get wish ana beft
# and oul
#
# iter:13899/20000 loss:1.8720186948776245
# generated sequence: Whi'ver love I feen I wored sech
# A men
# I aive when I
# you's one
#
# Ice and I'm tell there
# I kild forge
#
# iter:13999/20000 loss:1.8635540008544922
# generated sequence: When I see lord wern at bory telling ain', my prig
# be smould go!"
# "Is abreag three on Exper do?
# Recki
#
# iter:14099/20000 loss:1.8438034057617188
# generated sequence: Well
# Oull now I'll su'll been
# Lone and, go
# From I hor tos (meing I've a reat in you know you fuck to
#
# iter:14199/20000 loss:1.8837686777114868
# generated sequence: When your-bachaitiout out s uecisule out
# I kne I seeld wishings
# But beleed is teis
# Besteravel
# Sun
# Thi
#
# iter:14299/20000 loss:1.829275369644165
# generated sequence: We sugiom presers this the fid minsioppes one, to let's spere it righting even Rocked itthon me
# iead
#
# iter:14399/20000 loss:1.8267239332199097
# generated sequence: With a have through you ondone on, do, on? it more
#
# Wesperan you, no I you're
# Yeah!
# Na I bain to cali
#
# iter:14499/20000 loss:1.8934534788131714
# generated sequence: Womenthers
# So liat you besay low core I lone
# So hight you time you cry,
# This sour in all our
# Never me
#
# iter:14599/20000 loss:1.8608205318450928
# generated sequence: We's and say fust my fake hearting he chead,?, I me.
# He sousicinit so warts
# Now boing when when you w
#
# iter:14699/20000 loss:1.8187446594238281
# generated sequence: Where as fishou
# The kivs arrides.
# That your need what's doen world
# The Chate ever hey ever fried, daw
#
# iter:14799/20000 loss:1.8259742259979248
# generated sequence: Who anotanamonsher awause, doorss
# myor, in the bringway,
# But cleen.
# (I.'s rooe, bust I so knows chang
#
# iter:14899/20000 loss:1.8772393465042114
# generated sequence: When your muce on man. thases on erech lorl, on you, unetin's prelem
# I'm got EPruen
#
# Shyod
# Oh your r
#
# iter:14999/20000 loss:1.8091850280761719
# generated sequence: We late shen
# so my betcay
# There's at? you shay heaven
#
# Jut the ablie be
# All
# And to the meky whins you
#
# iter:15099/20000 loss:1.8586995601654053
# generated sequence: Wit's frive these there's & soullest the hands will Jadpling is prame it's thE Ur it's so hurrs bood
#
# iter:15199/20000 loss:1.8837635517120361
# generated sequence: With a the said to oughing mat You got pizy
#
# The now you, blad head it's buease in soffinds we workin
#
# iter:15299/20000 loss:1.8176589012145996
# generated sequence: We tendst tall enery are the mightent cis math
# You geegtes,
# I had and thrieas me I dow, you dady, ona
#
# iter:15399/20000 loss:1.8506237268447876
# generated sequence: Whes awaye,
#
# Swith so mear all gand)
# Just gonnay night no alinder than you and bean the headd
# So may
#
# iter:15499/20000 loss:1.8831124305725098
# generated sequence: We're needy baby
#
# Yeah
#
# Sometime in the siever emile stress of my bet of Cwancer sellike never two So
#
# iter:15599/20000 loss:1.8243917226791382
# generated sequence: Want to in that hoad
# All in ever finie injeat
# Buloning
# fous in there to making
# Sayhe I mect fisk for
#
# iter:15699/20000 loss:1.791792869567871
# generated sequence: Where like
# I wanta kn for a know dy]
# 're she give you dids think give may
# If you epery.
# Gonna breaker
#
# iter:15799/20000 loss:1.969523549079895
# generated sequence: We Pipding /ight
#
# Ih of think to men of you're for flowhel"""""Noudy)
# Dn is this
# lattersover it's ais
#
# iter:15899/20000 loss:1.7817351818084717
# generated sequence: When more never being hus, come in) tage the romby so on just canelife
# Apr, said Xelver get Strong
# I'
#
# iter:15999/20000 loss:1.851676106452942
# generated sequence: Whene
# So me in to tenting
#
# So and can gleting
# Stepped and just your chandfy's cleakine
# Was
# Evoleatw
# E
#
# iter:16099/20000 loss:2.3921124935150146
# generated sequence: Whect
# iffurr an Cabl
# I'm one you'ing
# Alees
# BCout che yith urlob
# yI'r stheme tuspfrove btr himmerd
# He
#
# iter:16199/20000 loss:2.340366840362549
# generated sequence: Within
# Uhl shing
# Do mesece
# rfon
#
# aishoe, oh
# Ih
# Shices on'tetshow,
# Breases s the dookion
# Tht male thon
#
# iter:16299/20000 loss:2.258207082748413
# generated sequence: Whe hen ooze ficllisw he hond iney ahee doum ghe Itung oofle ieare ume afrant
#
# e wake hourr areed afl
#
# iter:16399/20000 loss:2.8585927486419678
# generated sequence: Wanll.  la
# an
# t kem de.n th teflove t de velonouttuta f I tland
# e sn er tiot ba thter t mldeded sgil
#
# iter:16499/20000 loss:2.6894166469573975
# generated sequence: Whand
# Winmel serouspiimee tes sm
# I'thedSt bimen ast'ut
#
# Ash..ahe! ller ine
# Stan' hereat mheringoselik
#
# iter:16599/20000 loss:2.6797642707824707
# generated sequence: Waath. reLhereestt the
# TheavOslelendesn ww op ht ine osvein l' xtgreons pa poneaco
# i oh ailohl he ok
#
# iter:16699/20000 loss:2.6047279834747314
# generated sequence: Word ni oel do d gis
# Rednytvain'tht
# Bus ') t ci svergamgue icathe sindime
# miI Ir t
# (I thtay ine syk a
#
# iter:16799/20000 loss:2.554802656173706
# generated sequence: Whelly gy ha kn nttisnd fimy inoal s a the pe fpSt ts singr mn,
# At?
# ea govo bat govethe sts me whes a
#
# iter:16899/20000 loss:2.567629098892212
# generated sequence: Wan fo
# Beke be pi firoat aid oowe
# A ot fowo frwe,
# onhb
# d I muis slwio sawhe lothow so atius I whes tm
#
# iter:16999/20000 loss:2.5314712524414062
# generated sequence: Wassp
# O fomy ch painou shsich woig londe
# Ls soed tnde whLy
# E
# Wsll
# Dochess ck hedeco
# The ed foord
# Sh
#
# iter:17099/20000 loss:2.5178565979003906
# generated sequence: Wa non rone arl t mos ton' th rlOre the dn sp ad wou
# Tounto kiaut tt mind chly cauI
# Le che shs by dro
#
# iter:17199/20000 loss:2.5643980503082275
# generated sequence: WiEgs ho!NNr
# No do aht Ee Isyou wa Itk his I cad Bo Th
# ll
# KEs lou, o Is,eakch-thengou youo ya IvEioNo
#
# iter:17299/20000 loss:2.50956654548645
# generated sequence: Weallyta thast'twons bu weyora
# Bu
# (I's). bapecon wilinaor
# ainit Gou lot youthan'
# I'van, da sas thaave
#
# iter:17399/20000 loss:2.5121212005615234
# generated sequence: WaNn'shoong loug yoe? haig mpooseciteat yiome
# ntyenn witein aout'noned it ors
# (ronou'll hom the fillo
#
# iter:17499/20000 loss:2.4979324340820312
# generated sequence: We lldd hake 'n th aod
# Wh er
# Anktidd fe ough tnithr
# Buw a Te as, elliro ck noghwn't'm
#
# I'm ldy
# Welllo
#
# iter:17599/20000 loss:2.4777274131774902
# generated sequence: Whind gong yo
# In
# I haen Buand hae orev yout s
# sorenof
# Allt
# Wdowh
# ,rvec thar in'st
# Hat torky bl
# We
# OA
#
# iter:17699/20000 loss:2.5091702938079834
# generated sequence: Welfees a'msngOod
# Me lo'rgang
# emecttk
# Yom  ouat youn sn
# Wutheoue whendl
# (dithcagmit isrd fipeume ord
#
# iter:17799/20000 loss:2.5763909816741943
# generated sequence: Warn'min ihovindin op on, thindesr waf  ot) tor ciod wide
#
#
# C in the orcemind tevikrloure,
#
# hats heeo
#
# iter:17899/20000 loss:2.5453429222106934
# generated sequence: Weellinnin when hinmak I kou'tatl gowl t icis tot tha satithe ya ler Jay tope o Juthet moklarfe, cali
#
# iter:17999/20000 loss:2.5604119300842285
# generated sequence: Way hh (ta fodevog me
# e
#  ofscoreg dg,
# He an't fostisne yah,,!
# W  itha on thenof
# I eresiostlile
# N sor
#
# iter:18099/20000 loss:2.5190908908843994
# generated sequence: Wht an aoindeerliusc I, lousy Ea' iar ane th gom .me go himaopous aA rean beene th
# Mes ha Ohe whares.
#
# iter:18199/20000 loss:2.533156394958496
# generated sequence: Whindanlw ind
# Wad n
# H
# To aode tht
# E lollt ire
# Ius gon. soIn
# At keine uo at loo
# Arled wpdod
# I at lonia
#
# iter:18299/20000 loss:2.5405430793762207
# generated sequence: Wansighs In than ghtryondd ate bila the ll
# Te Ivey fe loc musws ilone ho be
# G ay
# I hhingat yorn' shs
#
# iter:18399/20000 loss:2.475691795349121
# generated sequence: Wet'lst iee be do ardvo I cll hancitd toer ghzevise
# As'nths I def ths thesesthoth the housnd the o du
#
# iter:18499/20000 loss:2.51029372215271
# generated sequence: We thtathcacelinder
# Put kevor epo
# Cly'san yok
# Winn cou mirin ta
# inndlevetonetl an thnun tot cee incin
#
# iter:18599/20000 loss:2.4789535999298096
# generated sequence: Wh(woT shade
# I om
# Fyo th  ouein'
#   fthisas hasn
# Yaure fest mpanoouloun e've tsindou we fhom rytyen't
#
# iter:18699/20000 loss:2.4610023498535156
# generated sequence: Wasthatem be mere mtaye gost bows sel the wes hesn'th. Guoutou inesere ainon you my thare
# Bit trin'of
#
# iter:18799/20000 loss:2.5062925815582275
# generated sequence: Whellre oure won'to her I nge
# The)sa wheras
# Tb ngB he
# Thispeck
# Yhitl m lamend-------- -| inou win the
#
# iter:18899/20000 loss:2.501589298248291
# generated sequence: Wh-|-ateak kenokt
# Cataedetreawk e hesond'slofa ind
# Becent welkld oke abeny you
# Ney y.
# Allal tom hilyi
#
# iter:18999/20000 loss:2.5629115104675293
# generated sequence: Whandat una sftou rhivom
# I bpcho meanto tho ma besso
# No beo
# He'me s oningio'dIt
# Intouy dou My oopaith
#
# iter:19099/20000 loss:2.497169256210327
# generated sequence: We--rg tore j tit,iree tinconghst snone out tiene
# Fuiliening il Soit tits sa ltt thyet
# se matime
# Wit
#
# iter:19199/20000 loss:2.4954843521118164
# generated sequence: Whellisi zpinging fonoraringmen hor uok me
# he bee th th you
# C.
# At mynongtken sinainghis s
# I me d n'r
#
# iter:19299/20000 loss:2.4862518310546875
# generated sequence: We ar
# Ho one ivgiseem
# The felo youb tmin'tsilom tilofe and thee domo'm be on
# Heer grem d th t sigze f
#
# iter:19399/20000 loss:2.524425506591797
# generated sequence: We-n t waco fy Con a arong yoreyo
# Ihy whiny
# Wncning tic lonfe, gong'm you allou o co bleyouo gc, ryt
#
# iter:19499/20000 loss:2.499958038330078
# generated sequence: Wallanyout o'slcec se be is
# Hes lllinity
# er skedgahe imee ane ni goth
# Ine sifeesom loui a w youcandew
#
# iter:19599/20000 loss:2.484382152557373
# generated sequence: Wanto nog ts atvealef ngisr
# H
# How Illy
# D bo m your th and
# Your  ay
# ne
# Ahet b al]you delo
# Yam cure ges
#
# iter:19699/20000 loss:2.471695899963379
# generated sequence: We-sy tt andeake lidnow oflon'sla ingaarovtey
# Is rtindait youlyt the mau yon ernl farov as"s itara ah
#
# iter:19799/20000 loss:2.495429039001465
# generated sequence: We coinea'd j coond sicy pisrim the fo
# I't, hag'mmeteave worm wism
# ksi a atlisac,ther aghait
#
# [[Vsra)
#
# iter:19899/20000 loss:2.524043560028076
# generated sequence: Whetttay whe, goscknin' gow dr aynde
# Thet yngh wiove (ne so
# A meer onk yond chen'thnethar ngeyouod ur
#
# iter:19999/20000 loss:2.506134510040283
# generated sequence: Wh ghe ab I ghts
# Al peeenis pigin ateddyks
# wt fatow ha wn
# Andat wa atne ak brl t ane o
# A l afrrldeei

# %% [markdown]
# #### Training Loss Curve

# %%
items = [ele.item() for ele in all_losses] 
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(items)
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
